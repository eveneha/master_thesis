# %%
# --- Data preprocessing & loading with SMOTE ---

AMII_CLASSES = ['N', 'S', 'V', 'F', 'Q']
num_classes = len(AMII_CLASSES)

#Apply Discrete Wavelet Transform (DWT) for denoising ECG signals.
def apply_dwt_denoising(ecg_signal, wavelet='db4', level=4):
    coeffs = pywt.wavedec(ecg_signal, wavelet, level=level)  # Decompose signal
    coeffs[1:] = [pywt.threshold(c, np.std(c) * 0.5, mode="soft") for c in coeffs[1:]]  # Threshold details
    return pywt.waverec(coeffs, wavelet)[:len(ecg_signal)]  # Reconstruct & trim

def load_data(csv_file):
    try:
        df = pd.read_csv(csv_file)
    except FileNotFoundError:
        print(f"File not found: {csv_file}")
        return None, None, None

    # --- Normalize ECG Signal ---
    ecg_sig = (df['MLII'].values.astype(np.float32) - np.mean(df['MLII'])) / np.std(df['MLII'])

    # --- Apply DWT for Denoising ---
    ecg_sig = apply_dwt_denoising(ecg_sig)  # 🔹 DWT applied here

    # Extract labeled events (R-peaks)
    label_series = df[df['Type'] != '-'][['Sample', 'Type']]
    r_peaks = label_series['Sample'].values.astype(int)

    return ecg_sig, label_series, r_peaks


# ECG Dataset with optional SMOTE balancing.
class ECGDataset(Dataset):
    def __init__(self, data_dir, beat_length=256, stride=1, apply_smote=True):
        super(ECGDataset, self).__init__()
        self.data_dir = data_dir
        self.beat_length = beat_length
        self.stride = stride
        self.apply_smote = apply_smote
        self.data_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]
        self.labeled_events = []  # Store ECG segments with filenames

        self.label_map = {label: index for index, label in enumerate(AMII_CLASSES)}
        print(self.label_map)
        self.class_counts = {label: 0 for label in AMII_CLASSES}  # Debugging class count

        for csv_file in self.data_files:
            ecg_sig, label_series, r_peaks = load_data(os.path.join(data_dir, csv_file))
            if ecg_sig is not None and len(r_peaks) > 0:
                for index, row in label_series.iterrows():
                    sample_number = int(row['Sample'])
                    label = self.label_map.get(row['Type'], -1)

                    if label != -1:
                        ecg_window = self.get_fixed_beat(ecg_sig, r_peaks, sample_number)

                        if ecg_window is not None:
                            self.labeled_events.append((csv_file, ecg_window, label))
                            self.class_counts[AMII_CLASSES[label]] += 1

        print(f"Initial class distribution: {self.class_counts}")

        # Apply SMOTE for balancing if enabled
        if self.apply_smote:
            self.apply_smote_balancing()

        # Convert dataset to PyTorch tensors
        self.labeled_events = [(f, torch.tensor(sig).float(), torch.tensor(lbl).long()) for f, sig, lbl in self.labeled_events]

    # Resample input to 256 samples
    def resample_ecg(self, ecg_segment, target_length=256):
        if len(ecg_segment) == target_length:
            return ecg_segment
        return scipy.signal.resample(ecg_segment, target_length)

    def get_fixed_beat(self, ecg_sig, r_peaks, sample_number):
        peak_idx = np.where(r_peaks == sample_number)[0]

        if len(peak_idx) == 0 or peak_idx[0] == 0 or peak_idx[0] >= len(r_peaks) - 1:
            return None  # Skip if at the boundary

        peak_idx = peak_idx[0]
        start_idx = r_peaks[peak_idx - 1]
        end_idx = r_peaks[peak_idx + 1]

        ecg_beat = ecg_sig[start_idx:end_idx]
        return self.resample_ecg(ecg_beat, self.beat_length)

    # Uses SMOTE to generate synthetic samples for the minority classes.
    def apply_smote_balancing(self):
        print("Applying SMOTE for class balancing...")

        # Extract features (beats) and labels
        X = np.array([sig for _, sig, _ in self.labeled_events])
        y = np.array([lbl for _, _, lbl in self.labeled_events])

        # Flatten ECG beats to 1D (necessary for SMOTE)
        X_flattened = X.reshape(X.shape[0], -1)  # Shape: (num_samples, beat_length)

        # Apply SMOTE
        smote = SMOTE(sampling_strategy='auto', random_state=42, k_neighbors=5)
        X_resampled, y_resampled = smote.fit_resample(X_flattened, y)

        # Reshape back to original form
        X_resampled = X_resampled.reshape(X_resampled.shape[0], self.beat_length)

        # Update labeled events
        self.labeled_events = [(None, x, int(y)) for x, y in zip(X_resampled, y_resampled)]

        # Update class counts
        new_class_counts = {label: np.sum(y_resampled == idx) for label, idx in self.label_map.items()}
        print(f"New class distribution after SMOTE: {new_class_counts}")

    def __len__(self):
        return len(self.labeled_events)

    def __getitem__(self, idx):
        _, ecg_beat, label = self.labeled_events[idx]
        #ecg_beat = ecg_beat.unsqueeze(0).unsqueeze(1)  # Add channel dimension for CNN
        ecg_beat = ecg_beat.view(1, 256, 1)

        return ecg_beat, label

# %%
# --- Load Data ---

csv_file_dir = '/content/drive/MyDrive/Master/Data/mitDB_AMII'
full_dataset = ECGDataset(csv_file_dir)
# Out:
# {'N': 0, 'S': 1, 'V': 2, 'F': 3, 'Q': 4}
# Initial class distribution: {'N': 89012, 'S': 2772, 'V': 7176, 'F': 802, 'Q': 6781}
# Applying SMOTE for class balancing...
# New class distribution after SMOTE: {'N': 89012, 'S': 89012, 'V': 89012, 'F': 89012, 'Q': 89012}

# %%
# plot to viz
# Select a random index from the dataset
sample_idx = np.random.randint(0, len(full_dataset))

# Fetch the sample
ecg_sample, label = full_dataset[sample_idx]

# Convert to numpy for plotting
ecg_sample_np = ecg_sample.squeeze().numpy()  # Remove channel dimension

# Plot the ECG beat
plt.figure(figsize=(8, 4))
plt.plot(ecg_sample_np, label=f"ECG Beat (Label: {label.item()})")
plt.title(f"ECG Beat from (Sample Index: {sample_idx})")
plt.xlabel("Time (samples)")
plt.ylabel("Normalized Amplitude")
plt.legend()
plt.grid(True)
plt.show()

# %%
class QuantizedTemporalBlock2d(nn.Module):
    def __init__(self, n_inputs, n_outputs, kernel_size, stride, dilation, dropout=0.2):
        super(QuantizedTemporalBlock2d, self).__init__()
        # Compute fixed, symmetric padding for the temporal dimension.
        fixed_padding = ((kernel_size - 1) * dilation) // 2

        # Input quantization identity
        #self.quant_inp = qnn.QuantIdentity(bit_width=8, act_quant=Int8ActPerTensorFloat)

        # Two quantized convolutional layers
        self.conv1 = qnn.QuantConv2d(
            n_inputs, n_outputs, kernel_size=(kernel_size, 1),
            stride=(stride, 1), padding=(fixed_padding, 0),
            dilation=(dilation, 1),
            weight_quant=Int8WeightPerTensorFloat,  # Quantizes weights to INT8
            input_quant=Int8ActPerTensorFloat,          # Quantizes activations to INT8
            weight_bit_width=8,
            act_bit_width=8,
            bias=False)
        self.conv2 = qnn.QuantConv2d(
            n_outputs, n_outputs, kernel_size=(kernel_size, 1),
            stride=(stride, 1), padding=(fixed_padding, 0),
            dilation=(dilation, 1),
            weight_quant=Int8WeightPerTensorFloat,  # Quantizes weights to INT8
            input_quant=Int8ActPerTensorFloat,          # Quantizes activations to INT8
            weight_bit_width=8,
            act_bit_width=8,
            bias=False)

        self.dropout = nn.Dropout(dropout)

        # QuantReLU after the conv branch (with quant tensor output)
        self.relu_after_conv = qnn.QuantReLU(return_quant_tensor=True)

        # **Uniform quantizers added on both branches:**
        #self.quant_main = qnn.QuantIdentity(bit_width=8, return_quant_tensor=True)
        #self.quant_res = qnn.QuantIdentity(bit_width=8, return_quant_tensor=True)

        # QuantReLU after the residual addition
        self.relu_after_residual = qnn.QuantReLU(return_quant_tensor=True)

        # Downsample (1×1 conv) for the skip connection if channel dimensions differ.
        if n_inputs != n_outputs:
            self.downsample = qnn.QuantConv2d(
                n_inputs, n_outputs, kernel_size=(1, 1),
                weight_quant=Int8WeightPerTensorFloat)
        else:
            self.downsample = None

    def forward(self, x):
        # Main branch:
        out = self.conv1(x)
        out = self.dropout(out)
        out = self.conv2(out)
        out = self.relu_after_conv(out).value  # unwrap quantized tensor after ReLU
        out = self.dropout(out)
        #out = self.quant_main(out).value         # apply uniform quantizer on main branch

        # Residual branch:
        #res = x if self.downsample is None else self.downsample(x)
        #res = self.quant_res(res).value          # apply uniform quantizer on residual branch

        # Add branches and apply final quantized activation.
        #out = out + res
        out = self.relu_after_residual(out).value

        return out





class QuantizedTCN2d(nn.Module):
    def __init__(self, num_inputs, num_outputs, num_channels, kernel_size, dropout, dilation_factor):
        super(QuantizedTCN2d, self).__init__()
        self.num_channels = num_channels
        self.temporal_blocks = nn.ModuleList()

        for i in range(len(num_channels)):
            dilation_size = dilation_factor ** i
            in_channels = num_inputs if i == 0 else num_channels[i - 1]
            out_channels = num_channels[i]
            # For conv2d, padding becomes (0, (kernel_size-1)*dilation)
            # padding = (kernel_size - 1) * dilation_size
            self.temporal_blocks.append(
                QuantizedTemporalBlock2d(in_channels, out_channels, kernel_size, stride=1,
                                           dilation=dilation_size, dropout=dropout))
        self.fc = qnn.QuantLinear(num_channels[-1], num_outputs, weight_quant=Int8WeightPerTensorFloat, input_quant=Int8ActPerTensorFloat, bias=False)

    def forward(self, x):
      for block in self.temporal_blocks:
          x = block(x)

      if hasattr(x, "value"):
          x = x.value

      # Average pooling to (1,1), then explicitly reshape (FINN compatible)
      x = F.adaptive_avg_pool2d(x, (1, 1))
      x = torch.flatten(x, start_dim=1)  # explicitly (batch_size, channels)

      x = self.fc(x)
      return x

# %%
# --- Model Config ---
## Create model

# --- Model Config ---
input_channels = 1      # 1 ECG channel
num_channels = [4, 8, 16]  # Number of channels at each block
output_channels = 5     # e.g., number of classes
kernel_size = 5
dilation_factor = 4
dropout = 0.074
lr = 0.008
batch_size = 256

# Instantiate the modified model
tcn = QuantizedTCN2d(input_channels, output_channels, num_channels, kernel_size, dropout, dilation_factor)

dummy_input = torch.randn(1, 1, 256, 1)  # Adjust dimensions if needed
tcn(dummy_input)

optimizer = optim.Adam(tcn.parameters(), lr=lr)

# Print model summary
summary(tcn, input_size=(1, 1, 256, 1))  # (batch_size, channels, sequence_length)
# Out:
# =============================================================================================================================
# Layer (type:depth-idx)                                                      Output Shape              Param #
# =============================================================================================================================
# QuantizedTCN2d                                                              [1, 5]                    --
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-1                                        [1, 4, 256, 1]            91
# │    │    └─QuantConv2d: 3-1                                                [1, 4, 256, 1]            21
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-9                                        --                        (recursive)
# │    │    └─QuantConv2d: 3-3                                                --                        (recursive)
# │    │    └─Dropout: 3-4                                                    [1, 4, 256, 1]            --
# │    │    └─QuantConv2d: 3-5                                                [1, 4, 256, 1]            81
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-9                                        --                        (recursive)
# │    │    └─QuantConv2d: 3-7                                                --                        (recursive)
# │    │    └─QuantReLU: 3-8                                                  [1, 4, 256, 1]            1
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-9                                        --                        (recursive)
# │    │    └─QuantReLU: 3-10                                                 --                        (recursive)
# │    │    └─Dropout: 3-11                                                   [1, 4, 256, 1]            --
# │    │    └─QuantReLU: 3-12                                                 [1, 4, 256, 1]            1
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-9                                        --                        (recursive)
# │    │    └─QuantReLU: 3-14                                                 --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-10                                       [1, 8, 256, 1]            363
# │    │    └─QuantConv2d: 3-15                                               [1, 8, 256, 1]            161
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-18                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-17                                               --                        (recursive)
# │    │    └─Dropout: 3-18                                                   [1, 8, 256, 1]            --
# │    │    └─QuantConv2d: 3-19                                               [1, 8, 256, 1]            321
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-18                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-21                                               --                        (recursive)
# │    │    └─QuantReLU: 3-22                                                 [1, 8, 256, 1]            1
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-18                                       --                        (recursive)
# │    │    └─QuantReLU: 3-24                                                 --                        (recursive)
# │    │    └─Dropout: 3-25                                                   [1, 8, 256, 1]            --
# │    │    └─QuantReLU: 3-26                                                 [1, 8, 256, 1]            1
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-18                                       --                        (recursive)
# │    │    └─QuantReLU: 3-28                                                 --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-19                                       [1, 16, 256, 1]           1,427
# │    │    └─QuantConv2d: 3-29                                               [1, 16, 256, 1]           641
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-27                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-31                                               --                        (recursive)
# │    │    └─Dropout: 3-32                                                   [1, 16, 256, 1]           --
# │    │    └─QuantConv2d: 3-33                                               [1, 16, 256, 1]           1,281
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-27                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-35                                               --                        (recursive)
# │    │    └─QuantReLU: 3-36                                                 [1, 16, 256, 1]           1
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-27                                       --                        (recursive)
# │    │    └─QuantReLU: 3-38                                                 --                        (recursive)
# │    │    └─Dropout: 3-39                                                   [1, 16, 256, 1]           --
# │    │    └─QuantReLU: 3-40                                                 [1, 16, 256, 1]           1
# ├─QuantLinear: 1-24                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-26                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-41                                 --                        (recursive)
# ├─ModuleList: 1-25                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-27                                       --                        (recursive)
# │    │    └─QuantReLU: 3-42                                                 --                        (recursive)
# ├─QuantLinear: 1-26                                                         [1, 5]                    --
# │    └─ActQuantProxyFromInjector: 2-28                                      [1, 16]                   --
# │    │    └─FusedActivationQuantProxy: 3-43                                 [1, 16]                   1
# │    └─WeightQuantProxyFromInjector: 2-29                                   [5, 16]                   --
# │    │    └─RescalingIntQuant: 3-44                                         [5, 16]                   80
# │    └─ActQuantProxyFromInjector: 2-30                                      [1, 5]                    --
# =============================================================================================================================
# Total params: 6,974
# Trainable params: 6,974
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0
# =============================================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# =============================================================================================================================

# %%
# Split training, validation and testing

train_size = 0.7
val_size = 0.15
test_size = 0.15
loss_function = "label_smoothing"
# Stratified Data Split (with reduced size)
labels = [label.item() for _, label  in full_dataset]

# First, split train + temp (validation+test)
train_idx, temp_idx = train_test_split(
    list(range(len(full_dataset))), test_size=1 - train_size, stratify=labels, random_state=42)

# Get labels for second split (validation/test)
temp_labels = [labels[i] for i in temp_idx]

val_idx, test_idx = train_test_split(
    temp_idx, test_size=test_size/(test_size + val_size), stratify=temp_labels, random_state=42)

train_dataset = torch.utils.data.Subset(full_dataset, train_idx)
val_dataset = torch.utils.data.Subset(full_dataset, val_idx)
test_dataset = torch.utils.data.Subset(full_dataset, test_idx)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

test_labels = [label.item() for _, label in test_dataset]
print("Unique labels in test set:", set(test_labels))


# Calculate class weights
labels = []
for _,label in full_dataset:
  labels.append(label)
class_counts = torch.bincount(torch.stack(labels))
class_weights = 1.0 / (class_counts + 1e-7)
print("Class Weights: ", class_weights)


# --- Define Loss and Optimizer ---
# --- Select Loss Function ---
if loss_function == "cross_entropy":
    criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
elif loss_function == "label_smoothing":
    criterion = nn.CrossEntropyLoss(weight=class_weights.to(device), label_smoothing=0.1)
# Out:
# Unique labels in test set: {0, 1, 2, 3, 4}
# Class Weights:  tensor([1.1234e-05, 1.1234e-05, 1.1234e-05, 1.1234e-05, 1.1234e-05])

# %%
# ---------------------- Training Parameters ----------------------
num_epochs = 5  # number of training loops over the training dataset

# Lists for plotting Loss
training_losses = []
validation_losses = []


# --- Logging with wandB ---
wandb.init(project="tcn_experiments")

wandb.config.num_channels = num_channels
wandb.config.kernel_size = kernel_size
wandb.config.dropout = dropout
wandb.config.batch_size = batch_size
wandb.config.learning_rate = lr


# ---------------------- Training Loop ----------------------
tcn.train()
tcn.to(device) # Transfer model to GPU

running_loss = 0
running_correct = 0

for epoch in range(num_epochs):
    total_loss = 0
    batch_num = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        #Transfer data to GPU
        inputs = inputs.to(device)
        targets = targets.to(device)

        #Zero the gradients
        optimizer.zero_grad()
        # Forward pass
        outputs = tcn(inputs) # apply the TCN to the input
        # Calculate the loss
        loss = criterion(outputs, targets)
        # Backpropagation
        loss.backward()
        # Update weights
        optimizer.step()

        running_loss += loss.item() # update running loss
        _, predicted = torch.max(outputs, 1) # get the class prediction
        running_correct += (predicted == targets).sum().item() # update running correct

        # Log the progress
        if batch_idx % 100 == 0:
            print(f"Epoch: {epoch+1}/{num_epochs}, Batch: {batch_idx}/{len(train_dataloader)}, Loss: {loss.item():.4f}")
            # writer.add_scalar("Training loss", running_loss / 100 , epoch * len(train_dataloader) + batch_idx)
            # writer.add_scalar("Accuracy", running_correct / 100 , epoch * len(train_dataloader) + batch_idx)
            running_loss = 0.0
            running_correct = 0

        total_loss += loss.item() # update total loss
        batch_num+=1

    training_loss_avg = total_loss / batch_num
    training_losses.append(training_loss_avg) # append training loss to the list
   # writer.add_scalar("Loss/Train", training_loss_avg, epoch)

    train_loss = total_loss / len(train_dataloader)

    # --- Validation ---
    tcn.eval()  # ✅ Switch to evaluation mode
    total_loss_val = 0
    batch_num_val = 0
    correct, total = 0, 0  # ✅ Initialize accuracy tracking

    with torch.no_grad():
        for batch_idx_val, (inputs_val, targets_val) in enumerate(val_dataloader):
            inputs_val, targets_val = inputs_val.to(device), targets_val.to(device)

            # Forward pass
            outputs_val = tcn(inputs_val)

            # Calculate loss
            loss_val = criterion(outputs_val, targets_val)
            total_loss_val += loss_val.item()
            batch_num_val += 1


            _, predicted = torch.max(outputs_val, 1)
            correct += (predicted == targets_val).sum().item()
            total += targets_val.size(0)

    val_loss_avg = total_loss_val / batch_num_val
    validation_losses.append(val_loss_avg)
    val_acc = correct / total

    # 🔹 Print validation results
    print(f"📊 Epoch {epoch+1}/{num_epochs}: Train Loss={train_loss:.4f}, Val Loss={val_loss_avg:.4f}, Val Acc={val_acc:.4f}")

    tcn.train()
# Out:
# Epoch: 1/5, Batch: 0/1217, Loss: 1.6092
# Epoch: 1/5, Batch: 100/1217, Loss: 0.9011
# Epoch: 1/5, Batch: 200/1217, Loss: 0.7586
# Epoch: 1/5, Batch: 300/1217, Loss: 0.7275
# Epoch: 1/5, Batch: 400/1217, Loss: 0.6534
# Epoch: 1/5, Batch: 500/1217, Loss: 0.6650
# Epoch: 1/5, Batch: 600/1217, Loss: 0.6725
# Epoch: 1/5, Batch: 700/1217, Loss: 0.6170
# Epoch: 1/5, Batch: 800/1217, Loss: 0.5749
# Epoch: 1/5, Batch: 900/1217, Loss: 0.6569
# Epoch: 1/5, Batch: 1000/1217, Loss: 0.6147
# Epoch: 1/5, Batch: 1100/1217, Loss: 0.6233
# Epoch: 1/5, Batch: 1200/1217, Loss: 0.6261
# 📊 Epoch 1/5: Train Loss=0.7133, Val Loss=0.5859, Val Acc=0.9324
# Epoch: 2/5, Batch: 0/1217, Loss: 0.6325
# Epoch: 2/5, Batch: 100/1217, Loss: 0.6414
# Epoch: 2/5, Batch: 200/1217, Loss: 0.6181
# Epoch: 2/5, Batch: 300/1217, Loss: 0.5741
# Epoch: 2/5, Batch: 400/1217, Loss: 0.5844
# Epoch: 2/5, Batch: 500/1217, Loss: 0.5786
# Epoch: 2/5, Batch: 600/1217, Loss: 0.5669
# Epoch: 2/5, Batch: 700/1217, Loss: 0.5897
# Epoch: 2/5, Batch: 800/1217, Loss: 0.5870
# Epoch: 2/5, Batch: 900/1217, Loss: 0.5681
# Epoch: 2/5, Batch: 1000/1217, Loss: 0.5575
# Epoch: 2/5, Batch: 1100/1217, Loss: 0.6319
# Epoch: 2/5, Batch: 1200/1217, Loss: 0.5842
# 📊 Epoch 2/5: Train Loss=0.5944, Val Loss=0.5553, Val Acc=0.9427
# Epoch: 3/5, Batch: 0/1217, Loss: 0.5884
# Epoch: 3/5, Batch: 100/1217, Loss: 0.5773
# Epoch: 3/5, Batch: 200/1217, Loss: 0.5478
# Epoch: 3/5, Batch: 300/1217, Loss: 0.5749
# Epoch: 3/5, Batch: 400/1217, Loss: 0.5742
# Epoch: 3/5, Batch: 500/1217, Loss: 0.5725
# Epoch: 3/5, Batch: 600/1217, Loss: 0.5649
# Epoch: 3/5, Batch: 700/1217, Loss: 0.5575
# Epoch: 3/5, Batch: 800/1217, Loss: 0.6009
# Epoch: 3/5, Batch: 900/1217, Loss: 0.5773
# Epoch: 3/5, Batch: 1000/1217, Loss: 0.5743
# Epoch: 3/5, Batch: 1100/1217, Loss: 0.5505
# Epoch: 3/5, Batch: 1200/1217, Loss: 0.6171
# 📊 Epoch 3/5: Train Loss=0.5774, Val Loss=0.5504, Val Acc=0.9456
# Epoch: 4/5, Batch: 0/1217, Loss: 0.5885
# Epoch: 4/5, Batch: 100/1217, Loss: 0.5644
# Epoch: 4/5, Batch: 200/1217, Loss: 0.6076
# Epoch: 4/5, Batch: 300/1217, Loss: 0.5923
# Epoch: 4/5, Batch: 400/1217, Loss: 0.5546
# Epoch: 4/5, Batch: 500/1217, Loss: 0.5635
# Epoch: 4/5, Batch: 600/1217, Loss: 0.5905
# Epoch: 4/5, Batch: 700/1217, Loss: 0.5637
# Epoch: 4/5, Batch: 800/1217, Loss: 0.5640
# Epoch: 4/5, Batch: 900/1217, Loss: 0.5764
# Epoch: 4/5, Batch: 1000/1217, Loss: 0.5639
# Epoch: 4/5, Batch: 1100/1217, Loss: 0.5557
# Epoch: 4/5, Batch: 1200/1217, Loss: 0.5487
# 📊 Epoch 4/5: Train Loss=0.5638, Val Loss=0.5273, Val Acc=0.9547
# Epoch: 5/5, Batch: 0/1217, Loss: 0.5467
# Epoch: 5/5, Batch: 100/1217, Loss: 0.5368
# Epoch: 5/5, Batch: 200/1217, Loss: 0.5273
# Epoch: 5/5, Batch: 300/1217, Loss: 0.5397
# Epoch: 5/5, Batch: 400/1217, Loss: 0.5772
# Epoch: 5/5, Batch: 500/1217, Loss: 0.5409
# Epoch: 5/5, Batch: 600/1217, Loss: 0.5496
# Epoch: 5/5, Batch: 700/1217, Loss: 0.5860
# Epoch: 5/5, Batch: 800/1217, Loss: 0.5388
# Epoch: 5/5, Batch: 900/1217, Loss: 0.5173
# Epoch: 5/5, Batch: 1000/1217, Loss: 0.5356
# Epoch: 5/5, Batch: 1100/1217, Loss: 0.5502
# Epoch: 5/5, Batch: 1200/1217, Loss: 0.5450
# 📊 Epoch 5/5: Train Loss=0.5538, Val Loss=0.5217, Val Acc=0.9574

# %%
# --- Evaluation ---

tcn.eval()  # Set the model to evaluation mode

all_preds = []
all_targets = []

test_loss = 0
correct, total = 0, 0

with torch.no_grad():
    for inputs, targets in test_dataloader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = tcn(inputs)

        loss = criterion(outputs, targets)
        test_loss += loss.item()

        _, predicted = torch.max(outputs, 1) # get the class prediction
        correct += (predicted == targets).sum().item()
        total += targets.size(0)
        all_preds.extend(predicted.cpu().numpy()) # store predictions
        all_targets.extend(targets.cpu().numpy()) # store target labels

test_loss /= len(test_dataloader)
test_accuracy = correct / total

# wandb.run.summary["Final test_loss"] = test_loss
# wandb.run.summary["Finnal test_accuracy"] = test_accuracy
# wandb.finish()
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# Generate Confusion Matrix
cm = confusion_matrix(all_targets, all_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=AMII_CLASSES, yticklabels=AMII_CLASSES)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

print("Unique values in all_targets:", np.unique(all_targets))
print("Unique values in all_preds:", np.unique(all_preds))


# Generate classification report
print("Classification Report:\n", classification_report(all_targets, all_preds, target_names=AMII_CLASSES, zero_division=0))

# Plotting Loss
plt.figure(figsize=(10, 5))
plt.plot(range(num_epochs), training_losses, label='Training Loss')
plt.plot(range(num_epochs), validation_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Curve')
plt.legend()
plt.grid(True)
plt.show()

# --- Compute Total F1-Scores ---
macro_f1 = f1_score(all_targets, all_preds, average="macro")
weighted_f1 = f1_score(all_targets, all_preds, average="weighted")

print(f"📊 **Total Macro F1-Score**: {macro_f1:.4f}")
print(f"📊 **Total Weighted F1-Score**: {weighted_f1:.4f}")
# Out:
# Test Loss: 0.5225, Test Accuracy: 0.9571
# Unique values in all_targets: [0 1 2 3 4]
# Unique values in all_preds: [0 1 2 3 4]
# Classification Report:
#                precision    recall  f1-score   support
#
#            N       0.96      0.92      0.94     13352
#            S       0.95      0.96      0.95     13352
#            V       0.97      0.94      0.96     13352
#            F       0.94      0.97      0.96     13352
#            Q       0.97      0.99      0.98     13352
#
#     accuracy                           0.96     66760
#    macro avg       0.96      0.96      0.96     66760
# weighted avg       0.96      0.96      0.96     66760
# 📊 **Total Macro F1-Score**: 0.9570
# 📊 **Total Weighted F1-Score**: 0.9570

# %%
# --- Save model ---
torch.save({
    'model_state_dict': tcn.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),  # If you want to save optimizer state
}, '/content/drive/MyDrive/Master/tcn_model_v31.pth')

print("Training Done, model weights are saved")
# Out:
# Training Done, model weights are saved

# %%
# CPU:
#checkpoint = torch.load('/content/drive/MyDrive/Master/tcn_model_v30.pth', map_location=torch.device('cpu'))


# GPU
checkpoint = torch.load('/content/drive/MyDrive/Master/tcn_model_v31.pth')
tcn.load_state_dict(checkpoint['model_state_dict'], strict=False)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])  # If needed
tcn.eval()
# Out:
# QuantizedTCN2d(
#   (temporal_blocks): ModuleList(
#     (0): QuantizedTemporalBlock2d(
#       (conv1): QuantConv2d(
#         1, 4, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (conv2): QuantConv2d(
#         4, 4, kernel_size=(5, 1), stride=(1, 1), padding=(2, 0), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (dropout): Dropout(p=0.074, inplace=False)
#       (relu_after_conv): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (relu_after_residual): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (downsample): QuantConv2d(
#         1, 4, kernel_size=(1, 1), stride=(1, 1)
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#     )
#     (1): QuantizedTemporalBlock2d(
#       (conv1): QuantConv2d(
#         4, 8, kernel_size=(5, 1), stride=(1, 1), padding=(8, 0), dilation=(4, 1), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (conv2): QuantConv2d(
#         8, 8, kernel_size=(5, 1), stride=(1, 1), padding=(8, 0), dilation=(4, 1), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (dropout): Dropout(p=0.074, inplace=False)
#       (relu_after_conv): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (relu_after_residual): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (downsample): QuantConv2d(
#         4, 8, kernel_size=(1, 1), stride=(1, 1)
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#     )
#     (2): QuantizedTemporalBlock2d(
#       (conv1): QuantConv2d(
#         8, 16, kernel_size=(5, 1), stride=(1, 1), padding=(32, 0), dilation=(16, 1), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (conv2): QuantConv2d(
#         16, 16, kernel_size=(5, 1), stride=(1, 1), padding=(32, 0), dilation=(16, 1), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (dropout): Dropout(p=0.074, inplace=False)
#       (relu_after_conv): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (relu_after_residual): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (downsample): QuantConv2d(
#         8, 16, kernel_size=(1, 1), stride=(1, 1)
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#     )
#   )
#   (fc): QuantLinear(
#     in_features=16, out_features=5, bias=False
#     (input_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#       (fused_activation_quant_proxy): FusedActivationQuantProxy(
#         (activation_impl): Identity()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClamp()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#             (input_view_impl): Identity()
#           )
#           (scaling_impl): ParameterFromRuntimeStatsScaling(
#             (stats_input_view_shape_impl): OverTensorView()
#             (stats): _Stats(
#               (stats_impl): AbsPercentile()
#             )
#             (restrict_scaling_impl): FloatRestrictValue()
#             (restrict_scaling): _RestrictValue(
#               (restrict_value_impl): FloatRestrictValue()
#             )
#             (clamp_scaling): _ClampValue(
#               (clamp_min_ste): ScalarClampMinSte()
#             )
#             (restrict_inplace_preprocess): Identity()
#             (restrict_preprocess): Identity()
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#     )
#     (output_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#     (weight_quant): WeightQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#       (tensor_quant): RescalingIntQuant(
#         (int_quant): IntQuant(
#           (float_to_int_impl): RoundSte()
#           (tensor_clamp_impl): TensorClampSte()
#           (delay_wrapper): DelayWrapper(
#             (delay_impl): _NoDelay()
#           )
#           (input_view_impl): Identity()
#         )
#         (scaling_impl): StatsFromParameterScaling(
#           (parameter_list_stats): _ParameterListStats(
#             (first_tracked_param): _ViewParameterWrapper(
#               (view_shape_impl): OverTensorView()
#             )
#             (stats): _Stats(
#               (stats_impl): AbsMax()
#             )
#           )
#           (stats_scaling_impl): _StatsScaling(
#             (affine_rescaling): Identity()
#             (restrict_clamp_scaling): _RestrictClampValue(
#               (clamp_min_ste): ScalarClampMinSte()
#               (restrict_value_impl): FloatRestrictValue()
#             )
#             (restrict_scaling_pre): Identity()
#             (restrict_scaling_impl): FloatRestrictValue()
#           )
#         )
#         (int_scaling_impl): IntScaling()
#         (zero_point_impl): ZeroZeroPoint(
#           (zero_point): StatelessBuffer()
#         )
#         (msb_clamp_bit_width_impl): BitWidthConst(
#           (bit_width): StatelessBuffer()
#         )
#       )
#     )
#     (bias_quant): BiasQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#   )
# )

# %%
from brevitas.export import export_qonnx

# scale_factor = 9.607829269953072e7  # example value from your Mul node

# with torch.no_grad():
#     # multiply final FC weights
#     tcn.fc.weight *= scale_factor
#     # if you had a bias and needed to fold it too:
#     # model.fc.bias *= scale_factor

tcn.eval()
tcn = tcn.to(device)
dummy_input = torch.randn(1, 1, 256, 1).to(device)

export_qonnx(tcn, dummy_input, export_path='tcn_v31.onnx', opset_version=9)
# Out:
# ir_version: 4
# producer_name: "pytorch"
# producer_version: "2.6.0"
# graph {
#   node {
#     input: "x.691"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_1_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/conv1/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/conv1/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/conv1/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/conv1/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/conv1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.0/conv1/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.0/conv1/Conv_output_0"
#     name: "/temporal_blocks.0/conv1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 2
#       ints: 0
#       ints: 2
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.0/conv1/Conv_output_0"
#     input: "/temporal_blocks.0/conv2/input_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/conv2/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/conv2/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/conv2/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv2/weight_quant/export_handler/Constant_1_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/conv2/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/conv2/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/conv2/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.0/conv2/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.0/conv2/Conv_output_0"
#     name: "/temporal_blocks.0/conv2/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 2
#       ints: 0
#       ints: 2
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.0/conv2/Conv_output_0"
#     output: "/temporal_blocks.0/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.0/relu_after_conv/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.0/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.0/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.0/relu_after_residual/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.0/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.1/conv1/input_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/conv1/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/conv1/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/conv1/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.1/conv1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/conv1/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/conv1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/conv1/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.1/conv1/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.1/conv1/Conv_output_0"
#     name: "/temporal_blocks.1/conv1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 4
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 8
#       ints: 0
#       ints: 8
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.1/conv1/Conv_output_0"
#     input: "/temporal_blocks.1/conv2/input_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/conv2/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/conv2/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/conv2/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.1/conv2/weight_quant/export_handler/Constant_1_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/conv2/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/conv2/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/conv2/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.1/conv2/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.1/conv2/Conv_output_0"
#     name: "/temporal_blocks.1/conv2/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 4
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 8
#       ints: 0
#       ints: 8
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.1/conv2/Conv_output_0"
#     output: "/temporal_blocks.1/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.1/relu_after_conv/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.1/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.1/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.1/relu_after_residual/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.1/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.2/conv1/input_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/conv1/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/conv1/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/conv1/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.2/conv1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/conv1/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/conv1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/conv1/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.2/conv1/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.2/conv1/Conv_output_0"
#     name: "/temporal_blocks.2/conv1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 16
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 32
#       ints: 0
#       ints: 32
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.2/conv1/Conv_output_0"
#     input: "/temporal_blocks.2/conv2/input_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/conv2/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/conv2/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/conv2/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.2/conv2/weight_quant/export_handler/Constant_1_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/conv2/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/conv2/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/conv2/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.2/conv2/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.2/conv2/Conv_output_0"
#     name: "/temporal_blocks.2/conv2/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 16
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 32
#       ints: 0
#       ints: 32
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.2/conv2/Conv_output_0"
#     output: "/temporal_blocks.2/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.2/relu_after_conv/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.2/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.2/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.2/relu_after_residual/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.2/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     output: "/GlobalAveragePool_output_0"
#     name: "/GlobalAveragePool"
#     op_type: "GlobalAveragePool"
#   }
#   node {
#     input: "/GlobalAveragePool_output_0"
#     output: "/Flatten_output_0"
#     name: "/Flatten"
#     op_type: "Flatten"
#     attribute {
#       name: "axis"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "/Flatten_output_0"
#     input: "/fc/input_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/fc/input_quant/export_handler/Quant_output_0"
#     name: "/fc/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/fc/weight_quant/export_handler/Constant_output_0"
#     input: "/fc/weight_quant/export_handler/Constant_1_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     output: "/fc/weight_quant/export_handler/Quant_output_0"
#     name: "/fc/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/fc/weight_quant/export_handler/Quant_output_0"
#     output: "/fc/Transpose_output_0"
#     name: "/fc/Transpose"
#     op_type: "Transpose"
#     attribute {
#       name: "perm"
#       ints: 1
#       ints: 0
#       type: INTS
#     }
#   }
#   node {
#     input: "/fc/input_quant/export_handler/Quant_output_0"
#     input: "/fc/Transpose_output_0"
#     output: "91"
#     name: "/fc/MatMul"
#     op_type: "MatMul"
#   }
#   name: "main_graph"
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     raw_data: "\000\000\000A"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_1_output_0"
#     raw_data: "\322Y\363<"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_2_output_0"
#     raw_data: "\000\000\000\000"
#   }
#   initializer {
#     dims: 4
#     dims: 1
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.0/conv1/weight_quant/export_handler/Constant_output_0"
#     raw_data: "d\272\300\277\353\250\256\277\255\217\024\277\370\205\212?\225\366\376?\030\243(?T\233\240\2754~\202\277\007\204\210\276\313\213\220>\313\213\020\276\351\207\014\277\007\204\010\277C|\000=)\302H?\221\264\272\277\334\252\260>6\237$?\317\315T?C|\000\276"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv1/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "C|\200<"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv2/input_quant/export_handler/Constant_output_0"
#     raw_data: "C\224\270<"
#   }
#   initializer {
#     dims: 4
#     dims: 4
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.0/conv2/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\267A\217>\267A\017=7\n\271>I\002?\275\333\302n\276\222Q\203\277\344-\036\277I\002?<\222Q\003>\222Q\203>\000\000\000\200\267\322\342\2767\n\271\276$\022\263\276\244\332\334\276D\204\275?\000"\247>I\002\277<\267\322b\276\267A\017\276\3331\033?\356\272\364>\244I\211>\267\322\342>\222Q\203\276\333\302\356>\267A\017\275\267\322b\277\300=\022\277\267A\017=[\372D?\267\322\342>\000\000\000\200\3331\233\276\000\263\372\276I\002?<\3331\233>\262\303\215?\367%$?w\356M\277w\356M\2777\n9\277\t\036*\277\267A\017\277\222Q\003\276\000"'\276\267A\017=$\0223>\222\342\326>\200\352\320>\356)!\277\244I\211\276\267A\017\275I\002?=\200\352\320>I\002?>\200\352\320\276I\002?=\367%$\2777\n9\277\356)!\277\222Q\203>n\362\312>\222Q\203>\356\272t?\3331\033>\244I\t?\244\332\?R\376A?\244\332\334>\222Q\203\276\222Q\203>\267\322\342>\3331\033?\267A\017?\356)\241\276\256E\014\277\000"'\277\267\322\342\276I\002?<"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv2/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "I\002?<"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     raw_data: "\342[|>"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     raw_data: "\364Y\237>"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/conv1/input_quant/export_handler/Constant_output_0"
#     raw_data: "\264p\354>"
#   }
#   initializer {
#     dims: 8
#     dims: 4
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.1/conv1/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\251\266\300=:\247\233>\242\211\317\275\022\231t\276& H\276\377\210\220>\225/\355<\304j\005\277\275=\024\277@\324\214>\260\343\261=\242\211\317=\225/\355=\234\\336=\225/\355\276,M9\276\216\002\374\275\242\211O=\266\020#\276Z\021\342>\242\211\317\276\000\000\000\000gk\304>\202\037\211\276\000\000\000\200\304j\005>\275=\024>\327z\351>\304j\205=\202\037\211>6Uk\277\266\020#>\030\306e>\022\231t\276\304j\205\276\037\363V>\225/\355\274{\362\227>\275=\024\276e\220\003\277\216\002|>\251\266@>\251\266@\276a>\323\276\225/\355\274\216\002\374>\260\3431?\275=\224>\225/\355\273{\362\227\276\216\002\374=\260\343\261<\005\266\201\276\005\266\001\277\234\\336\276\377\210\020?\216\002\374=\037\363V>\361.\256\276n\230\265\276\231\201\035?\225/m=3z*\276:\247\033>W6!?\034\030\026?\225/m\275\242\211O=\225/\355<\304j\205>\216\002\374>\216\002\374\276\370[\237\276\022\231t\276,M\271>\225/\355\275\225/\355\273& H\276\234\\336\275\275=\224\275\333\314\031\277\260\343\261\275\260\343\261\274\275=\024>\037\363V>\361.\256\276M\267\377\276\370[\237>{\362\227>\275=\024\276@\324\014\276\234\\336\275\225/\355\273\225/m\275& \310\276\275=\024\277& H>\202\037\211>\225/m\274\341\371\n?\225/\355\275\260\343\261<\216\002\374=\333\314\031\277M\267\377\276\225/m\275:\247\033>\260\343\261<gk\304\276\260\343\261<\037\363V\276\242\211O\275\260\3431\275\251\266\300\275\202\037\211>@\324\014\277S\344\360\276\225/\355=\335\247\332>\304j\005?\304j\205\275\266\020#>\000\000\000\200=\202\?\234\\336=\260\3431\275\225/m<\251\266\300\275:\247\033?\202\037\211\276@\324\014\276\377\210\220\276\335\247\332\276\304j\205\275\370[\037\277\260\343\261>\251\266@\276\216\002|>\242\211O>\260\343\261\274\225/\355;u\305&?\234\\336>\234\\336\275\225/m\2753z\252\276\202\037\211>\000\000\000\0003z\252\276\251\266@\276\275=\024\275\225/m\275\327z\351>\225/\355<\234\\336\275gk\304\276\005\266\201\276\377\210\220>\216\002|>M\267\377>"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/conv1/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "\225/\355;"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/conv2/input_quant/export_handler/Constant_output_0"
#     raw_data: "\003\212\272>"
#   }
#   initializer {
#     dims: 8
#     dims: 8
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.1/conv2/weight_quant/export_handler/Constant_output_0"
#     raw_data: "8\300A>=@Q\276-\000\033>+@\023?@\340\334>:\200\311=H\000x\274+@\023\276*`\217\2763`\256\2766\000\272=?\000Y=?\000Y\276A\300`>4@2>?\000Y>4@2>8\300A\276A\300`\2769\240\305>-\000\033=9\240\305\2763`\256\276F@p\276?\000\331\275(\200\213=?\000Y\275H\000\370=2\200\252=A\300`\276+@\023\276<`\315\276)p\r\277J\300\177\2762\200*\277'\240\207>-\000\233=2\200*>-\000\033>=@Q\276-\000\233\275\000\000\000\200?\000\331=-\000\233\2756\000:\276:\200\311\275F@\360>?\000\331>*`\217>B\240\344>=@Q?<`\315>-\000\233=:\200I>-\000\233\275/\300">H\000\370\273-\000\233\275H\000x=,\020\031?D\200\350\2756\000:\275A\300`>D\200\350=H\000\370<:\200I\276?\000Y\275H\000x<6\000:\275&\300\003\276F@p>6\000:=2\200*>4@2>A\300\340>G\020v\277&\300\003\2772\200*\277=@\321\276&\300\203\276H\000x\2760\240\246\276/\300"\276&\300\203\2766\000:\276-\000\233>=@\321>(\200\213=6\000:=, \227>> \325\276H\000\370\273D\200\350=H\000\370=?\000\331=*`\217\276-\000\033\275H\000x>-\000\233>-\000\233>:\200\311==@\321>-\000\033?9\240\305\2761\220(\2776\000:=-\000\033\275'\240\207\276A\300`\276?\000\331\275'\260\005?.\340\236>J\300\177>H\000x>+@\023>-\000\033\276-\000\033=-\000\233=(\200\213=(\200\213>?\000\331>A\300\340>?\000\331\275-\000\033\2756\000:>A\320^??\000Y\276?\000Y\2769\240\305\276?\000Y>H\000\370\273/\320 ?*`\217>2\200*\276-\000\033\276A\300`\276&\300\003>/\300\242>6\000\272\274D\200h\276:\200I\276&\300\203\2766\000:=<`\315>D\200\350\276&\300\003?4@2\276D\200\350\275(\200\013>/\300\242>*`\217\276F@p>:\200\311=H\000\370<?\000\331\275J\300\177>F@p><`\315\2766\000\272\274D\200h>.\340\236\276:\200I\276+0\025?4@2\276H\000x\276> \325>, \027?:\200I>H\000x\276/\300"\2762\200\252\275?\000Y\2752\200\252=-\000\033>F@p\2768\300A\276<`\315\276, \027\277*P\021?'\240\207>(\200\013?&\300\203>2\200*>6\000:\276@\340\334>2\200\252=H\000\370>'\240\007?(\200\013\276H\000x\275(\200\213>.\340\236\276-\000\233\275\000\000\000\000D\200\350=@\340\334\2762\200*>H\000x=0\260$\277?\000Y\276-\000\233=2\200\252=:\200\311='\240\207>(\200\013>+@\223\276*`\017\277:\200\311\2762\200\252=F@p>0\240&\277=@Q\277-\000\033\2763`\256\276H\000\370\273,\020\031??\000Y>8\300A\2769\240\305\2769\240E\277F@p\276D\200h>-\000\233>=@\321>=@Q>-\000\033\2758\300\301>.\360\034?2\200*?2p,?/\300"\276H\000\370\274?\000\331\2752\200\252=H\000\370=/\300\242>6\000\272>=@Q>/\300\242>I\340\373>3`\256>, \027?6\000:\276A\300`\276(\200\013\277(\200\013\276-\000\033\275H\000\370=5 \266>+@\223>?\000Y\276/\300\242\2766\000\272\276?\000\331\275\000\000\000\200H\000x\275H\000x\275+@\023\276-\000\033>G \364>(\200\213>5 \266>F@p>3`\256>8\300A\276H\000\370>6\000:=(\200\213\275/\300"\2766\000\272\276-\000\233\276A\300`\2766\000\272=*`\217>:\200I\276:\200I>?\000Y\276:\200I\276-\000\033\277,\020\031\277/\300"\276:\200\311\276(\200\013\276-\000\233\2752\200*?6\000:=\000\000\000\200&\300\003>?\000Y\276:\200I\276?\000Y\275?\000\331\275J\300\377>3`\256\2769\260C\277*`\217>8\300A>-\000\033\275(\200\213=:\200I\276(\200\213\275D\200\350\275<`\315\276:\200I\2766\000:=6\000\272\275:\200\311\276?\000Y\276.\340\036?=@Q?6\000:=:\200I>H\000\370;, \027\2776\000:\2778\300A>3`\256\276, \227\276:\200\311=2\200\252="
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/conv2/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "H\000\370;"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     raw_data: "\244@'?"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     raw_data: "\320v1?"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/conv1/input_quant/export_handler/Constant_output_0"
#     raw_data: "\322\t\317?"
#   }
#   initializer {
#     dims: 16
#     dims: 8
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.2/conv1/weight_quant/export_handler/Constant_output_0"
#     raw_data: "t\354\246\275\256b\372\275t\354\246\275t\354\246>7g\240? \205e\276t\354\246\274\255}\234\276\256bz\275\346\016\222=\000\000\000\200\036\240\007\276t\354&\276\221\247\320>\036\240\007>t\354&<;[1>IF\227\276\036\240\207>l\004\005?\221\247P=\346\016\222\275;[1>\036\240\007>\321 h?\346\016\022\276;[1>\255}\034\276\036\240\007\276\365\336\325>\256b\372<IF\227>\346\016\022>t\354&\274\237\222\266>\330#\254\276t\354&>;[1>\256bz\275\255}\034?f\001\301>\346\016\222\275\256bz\275\002\312\273\275f\001A?\256b\372\275J+\365> \205\345\275;[1\276\221\247P>\274M\340\276t\354&=IF\227\276\202\327\214>t\354\246=;[\261\276\346\016\022>\256bz=\221\247P=[%\216?\036\240\207>\347\363o\276\221\247P\276\221\247P\275\373\341\231?\202\327\014?t\354&>t\354\246\275\221\247P>\221\247P>J+\365>\373\341\031?t\354&<l\004\005?\221\247P\275\255}\234\276;[1\276\330#\254\276\202\327\014\277\347\363\357>IF\227>\256bz\275\221\247P\275\346\016\222\276 \205e>\000\000\000\200f\001\301>\347\363o>\255}\034>t\354&=\036\240\007?\256bz\275-p\313\276;[1>t\354&<4s\017\277 \205\345=t\354\246\275;[1?\002\312\273=t\354\246\276t\354&\275;[1> \205\345\275-p\313\276 \205\345= \205\345=\255}\234\276\237\222\266\276-p\313\276\255}\034>\246zX\277&\210)?_\031\037\277\203\274\352\276\346\016\222=t\354\246\276\221\247\320\275\211\277.\277 \205\345>\221\247P\276IF\227>\256bz=\346\016\022>\002\312\273\275-p\313\276 \205\345\275\274M\340\276\036\240\207>\221\247P>\022\232\377>\036\240\007>\203\274\352>t\354\246=;[\261>X\026[\277t\354\246>\002\312\273=\022\232\377>_\031\037?\002\312\273\275\3128F\276\002\312;\276\202\327\214>IF\227?\256b\372=\256b\372=\346\016\022\276\020\265\241\276-p\313>\221\247\320\275\374\306w\277;[1\276\221\247\320\276\221\247P\275-p\313\276\036\240\007\277;[\261>\221\247P\275\036\240\007\277IF\227>;[1>;[\261>\221\247P>\202\327\014?f\001\301>-pK\277\273h\202>\002\312\273>t\354&<\256b\372\275\221\247P\275X\026[>t\354&\274\002\312;\276\221\247P\276\255}\034\276\036\240\207>\346\016\022\277\n\262]\277\255}\034\276X\026\333\276 \205\345\275_\031\037\277\273h\002\277\237\2226?;[1\276t\354&\275t\354&>CCS?\036\240\007>\273h\202\276\346\016\222\276\274M`\277\255}\034\276\221\247\320=\002\312\273=t\354\246>t\354&=t\354\246=\256b\372<\221\247P\275\346\016\222\276IF\227\276;[\261\276\020\265!?IF\027?\202\327\214\276\036\240\007\276t\354\246<\211\277.?\255}\234\276\347\363o\276\3128F\276\036\240\207>\221\247P\275 \205\345\276;[1>\036\240\007>\255}\034\276X\026\333\276X\026[\276\221\247P=\347\363o\276\002\312\273=\002\312;>\346\016\022\276\256bz\275\273h\202>\002\312\273\2765Xm?\256bz\275\202\327\214> \205\345=t\354&=\020\265\241?|\324H?;[1>\346\016\222\275\221\247P>t\354\246<;[\261\276f\001\301>f\001A\277\256bz=IF\227\276\346\016\022>t\354&?;[1\277-p\313\276X\026[\276\346\016\222\275\256bz=\256b\372\274t\354\246>\202\327\214>t\354\246\274\221\247P\276 \205\345\275\3128F\276\273h\202\276;[1>\346\016\222>\330#\254\276\256bz\276\036\240\007\276\256b\372\275\346\016\222=;[1\276t\354&<\202\327\214\276\347\363o\277\256bz>\002\312\273=`\376|?\346\016\222=\3128\306\276\002\312;?\256b\372=\022\232\177?\346\016\022>\255}\034>\255}\234\276\255}\034\276\346\016\022\276\347\363o>\346\016\222\276\256bz\275\255}\034>J+\365>\256bz\2754s\017\277t\354&\274\227\252\024?\3128F\276\255}\234>&\210)\277\274M\340>\347\363\357\276\373\341\031?\255}\034\276t\354\246=\346\016\022\2764s\017\277\221\247P>X\026[>t\354&\274\221\247P\275Q.9?t\354&<\036\240\007>;[1>\273h\202\276\255}\034\277f\001\301\276\036\240\007\276\330#\254\276\036\240\007?\237\2226\277\256b\372\274 \205e\276|\324H?\255}\234>\002\312\273>\237\222\266\276\3128F\276\221\247P\276t\354&>t\354&\274\221\247\320=\3128F>\346\016\222=t\354&\276-p\313\276\273h\202>IF\027?J+\365>\221\247\320\275\255}\034>\346\016\022\276\255}\234>5Xm?\036\240\007\276t\354\246\274IF\227\276\036\240\207\276\273h\202>t\354&=\221\247P\276;[1?t\354\246\275t\354&=\256bz\2754s\017\277 \205e>\256bz\276\273h\002\277\256b\372\274\346\016\222\276\273h\202>\000\000\000 ...
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/conv1/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "t\354&<"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/conv2/input_quant/export_handler/Constant_output_0"
#     raw_data: "qF\231?"
#   }
#   initializer {
#     dims: 16
#     dims: 16
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.2/conv2/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\004wf=$\250I\276\004wf\274C\331,\275C\331,\276C\331\254\275\367\327\032\277\362\242\201>t\336t\276C\331\254\275\323q\236\276\004wf<LC\337>\274\252\355>\263@\273>\004wf<\362\242\201>\004w\346=b\n\220\275\362\242\001\276\004wf\277\252\326\210\276kt\302\276\316<\005\277\323q\236>yr\247\277C\331,\275\033>\227\276C\331,>\004wf\276\362\242\201>b\n\220\276kt\302>C\331,\277\334\333\320>\224\017X\276\206p\014?C\331,\276$\250I\276C\331\254\275C\331\254\276C\331,=\224\017\330\276\323q\036\276\033>\227>\367\327\032?\270uT\277LC\337\276C\331,>\033>\227>C\331,\275\033>\227\276\224\017X>C\331,>$\250\311=\252\326\210>\004w\346\275\263@;\276\263@\273>\263@;?\263@\273\276$\250I\277\362\242\201\276\362\242\201\276\004w\346\275$\250\311\276\263@;\276ktB?\217\332>?\000\000\000\200\334\333P\277\263@;\276b\n\020>kt\302\276\252\326\210\276C\331\254>C\331,\275\323q\036\276\263@;>\323q\236\276\004w\346<t\336t\276\252\326\010\277\224\017X\277\033>\227\276$\250I\276C\331\254\275LC_\277\000\000\000\000t\336t\276\263@;\276\263@;\276\004w\346>$\250\311>-q\225?$\250\311\276$\250\311=\004wf=\367\327\032\277\004w\346\276\323q\036\277b\n\220\276\217\332>\277\004w\346=C\331\254=C\331\254\275\323q\036>\004w\346=C\331\254=$\250I\276C\331\254\275\033>\227\276\004w\346\276b\n\220\275C\331,=\334\333P?t\336t\276\362\242\001>\000\000\000\000$\250\311>b\n\220\275\033>\027\277b\n\220\276\323q\036\277\373\0144\277\362\242\001\276b\n\220=\263@;>\004wf\276\323q\036\276\000\000\000\200\362\242\201>$\250I\276G\016F\277\000\000\000\000\033>\027?\004wf\275\252\326\010?\362\242\201\276\263@\273\276\004wf\276\323q\036\276\263@;\276\004wf=\323q\036\277b\n\220\276$\250I>\004w\346<\004w\346\274$\250\311=\263@\273\277\004w\346=C\331,=\362\242\001>\010\254\177\277\004wf\275\362\242\001\277\334\333\320\276$\250\311\275\004w\346<\257\013"\277\000\000\000\000b\n\220\276\206p\014\277\004w\346<$\250I\276\004w\346\274$\250\311\275\362\242\001\277\004wf\276\252\326\210?C\331,=$\250\311=\362\242\201\276ktB?\000BM?LC\337\276\004w\346\274\224\017\330>\224\017X\276\033>\227\277t\336t>\257\013"\277\327\2467\277C\331,>$\250\311>kt\302\276b\n\020\276b\n\020\276\263@;>\004w\346\275t\336t\276\033>\227>\224\017X>\362\242\001>C\331,>C\331,>\323q\036?\004w\346\275b\n\220=C\331,\275\224\017X\276\224\017X\276\217\332>\277\224\017X>\004w\346\276\323q\236>\373\014\264\276\004w\346\274LC\337>b\n\020\276$\250I>\004w\346\275$\250I\276\373\014\264>t\336t>\004w\346\274C\331\254=\323q\236>\004w\346<\004wf\275$\250\311=kt\302\276\263@;\277C\331\254\275b\n\220>\224\017X?$\250\311\275LC\337\276\004w\346=\362\242\201\276\323q\236\277\334\333\320\276\004w\346<\213\245\245>b\n\220=C\331,\276t\336t\276G\016F\277\213\245\245\276\004w\346<\004w\346=\004wf=\033>\227>\004wf=\263@;\277C\331\254=\004w\346\275\274\252\355>\323q\036\276\033>\227\276\033>\027\277\004w\346<C\331,=C\331,\275C\331\254\275\263@;\276\316<\005?\323q\236\276\301>\240?$\250I>\224\017X\276\004wf=\206p\014\277(\335b\277\004wf\276\004wf\276C\331\254>\263@;>\252\326\010\277\004wf>\362\242\001>\004wf<$\250\311\276\270uT\277LC\337\276\373\014\264\276\004w\346=\033>\027?t\336t\276\004w\346>\252\326\210\276\004wf=\305s\271\277\362\242\001>\270uT?$\250I>\323q\036\276\367\327\032?\033>\227>b\n\220=$\250I>b\n\220>\362\242\201>\224\017\330>\224\017X>b\n\020\276?\244\023?\033>\227\276\224\017X\276C\331\254=\004w\346\274\213\245\245>kt\302\276$\250\311\275,\022\374>\362\242\201?\206p\014?\206p\014\277-q\225?\340\020j\277C\331\254\276b\n\220\276b\n\020>\033>\027\277\224\017X\276b\n\220=t\336\364\276\004wf\276\263@;\277b\n\220\275\373\014\264\276t\336t\277\323q\036\277b\n\220\275\263@\273>\033>\027\277\004w\346\275\316<\005\277\263@;\276$\250\311=\004w\346<LC\337>\004wf=\362\242\201\276\004wf\276C\331,=\316<\005\277\263@;\277\327\2467?C\331,=C\331,>C\331\254\275\305s\271\277t\336\364\276$\250I\276\362\242\001>\323q\036\276b\n\020>C\331,\275b\n\220\276\373\014\264\276\004wf<C\331,\275\033>\027?\323q\036\276\224\017X>\362\242\001>\274\t\207\277\230\243\21 ...
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/conv2/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "\004wf<"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     raw_data: "\261\3677?"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     raw_data: "\017\262=?"
#   }
#   initializer {
#     data_type: 1
#     name: "/fc/input_quant/export_handler/Constant_output_0"
#     raw_data: "\037\231\364="
#   }
#   initializer {
#     dims: 5
#     dims: 16
#     data_type: 1
#     name: "/fc/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\217l\021>\0307\035\275"j\312\276\007\242\005>U\2728>\203\250\274=\013sH\276\240\001)\276\275Z\025>\203\250<=\376\256\363>\373\3350>v\344g\276\203\250<\274\260\226\300\276|F\322\276\321\300o>Y\213{\2755\220\t>Y\213{;\376\256s\276B\224\371\276\336\204\304=\243\322k>5\220\t\276r\023\245="j\312\276\373\335\260\276\315\357\254=\036\231\207>\000\000\000\000\217l\221>\327"\332\276\315\357\254>\0307\235<fOP\276yu\217>Y\213\373;\275Z\225>\240\001)\276l\261\272\276\203\250\274\274\243\322k\275\315\357\254=\0307\035\275\223=\324=\0307\035\275\033\010`>(\3144\276\0307\235=\206y\177>\0307\235\274\332\263\201\276\007\242\005\276U\2728>\356\031\334>\021\325\262>\0307\035\276Y\213{\274\266\370\252>\266\370\252\276"j\312\276\007\242\205=\243\322k\275Y\213{<\344\346\256\276\315\357,=\300+X\276Y\213{\274Y\213\373\275\203\250<\276OX\316\276\231\237\276>\001@\233>\376\256\363=\007\242\205=\231\237\276>Y\213{\276\007\242\005>8aL="
#   }
#   initializer {
#     data_type: 1
#     name: "/fc/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "Y\213{;"
#   }
#   input {
#     name: "x.691"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "91"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 5
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/conv1/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/conv1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/conv2/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/conv2/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/conv1/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/conv1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/conv2/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/conv2/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/conv1/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/conv1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/conv2/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/conv2/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/fc/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/fc/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 9
# }
# opset_import {
#   domain: "onnx.brevitas"
#   version: 1
# }

# %%
# !ls -l
from google.colab import files
files.download('tcn_v31.onnx')


#files.download('/content/drive/MyDrive/Master/tcn_model_v31.pth')
# Out:
# total 40
# drwx------  6 root root  4096 Mar 21 07:48 drive
# drwxr-xr-x  1 root root  4096 Mar 19 13:34 sample_data
# -rw-r--r--  1 root root 28174 Mar 21 13:54 tcn_v31.onnx
# drwxr-xr-x 15 root root  4096 Mar 21 13:50 wandb
