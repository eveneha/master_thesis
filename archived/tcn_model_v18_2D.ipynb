# %%
# --- Run Imports ---

import os
import time

import numpy as np
import pandas as pd
import csv
import scipy.signal
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split, Subset
from torch.utils.tensorboard import SummaryWriter
from torchinfo import summary

from collections import defaultdict
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from sklearn.model_selection import train_test_split

import seaborn as sns
import optuna
from imblearn.over_sampling import SMOTE
import wandb
import pywt

import brevitas.nn as qnn
from brevitas.quant import Int8WeightPerTensorFloat
from brevitas.quant import Uint8ActPerTensorFloat, Int8ActPerTensorFloat
import brevitas.onnx as bo
from brevitas.inject.defaults import RoundTo8bit



# Use GPU if Available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# --- Data preprocessing & loading with SMOTE ---

AMII_CLASSES = ['N', 'S', 'V', 'F', 'Q']
num_classes = len(AMII_CLASSES)

#Apply Discrete Wavelet Transform (DWT) for denoising ECG signals.
def apply_dwt_denoising(ecg_signal, wavelet='db4', level=4):
    coeffs = pywt.wavedec(ecg_signal, wavelet, level=level)  # Decompose signal
    coeffs[1:] = [pywt.threshold(c, np.std(c) * 0.5, mode="soft") for c in coeffs[1:]]  # Threshold details
    return pywt.waverec(coeffs, wavelet)[:len(ecg_signal)]  # Reconstruct & trim

def load_data(csv_file):
    try:
        df = pd.read_csv(csv_file)
    except FileNotFoundError:
        print(f"File not found: {csv_file}")
        return None, None, None

    # --- Normalize ECG Signal ---
    ecg_sig = (df['MLII'].values.astype(np.float32) - np.mean(df['MLII'])) / np.std(df['MLII'])

    # --- Apply DWT for Denoising ---
    ecg_sig = apply_dwt_denoising(ecg_sig)  # 🔹 DWT applied here

    # Extract labeled events (R-peaks)
    label_series = df[df['Type'] != '-'][['Sample', 'Type']]
    r_peaks = label_series['Sample'].values.astype(int)

    return ecg_sig, label_series, r_peaks


# ECG Dataset with optional SMOTE balancing.
class ECGDataset(Dataset):
    def __init__(self, data_dir, beat_length=256, stride=1, apply_smote=True):
        super(ECGDataset, self).__init__()
        self.data_dir = data_dir
        self.beat_length = beat_length
        self.stride = stride
        self.apply_smote = apply_smote
        self.data_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]
        self.labeled_events = []  # Store ECG segments with filenames

        self.label_map = {label: index for index, label in enumerate(AMII_CLASSES)}
        print(self.label_map)
        self.class_counts = {label: 0 for label in AMII_CLASSES}  # Debugging class count

        for csv_file in self.data_files:
            ecg_sig, label_series, r_peaks = load_data(os.path.join(data_dir, csv_file))
            if ecg_sig is not None and len(r_peaks) > 0:
                for index, row in label_series.iterrows():
                    sample_number = int(row['Sample'])
                    label = self.label_map.get(row['Type'], -1)

                    if label != -1:
                        ecg_window = self.get_fixed_beat(ecg_sig, r_peaks, sample_number)

                        if ecg_window is not None:
                            self.labeled_events.append((csv_file, ecg_window, label))
                            self.class_counts[AMII_CLASSES[label]] += 1

        print(f"Initial class distribution: {self.class_counts}")

        # Apply SMOTE for balancing if enabled
        if self.apply_smote:
            self.apply_smote_balancing()

        # Convert dataset to PyTorch tensors
        self.labeled_events = [(f, torch.tensor(sig).float(), torch.tensor(lbl).long()) for f, sig, lbl in self.labeled_events]

    # Resample input to 256 samples
    def resample_ecg(self, ecg_segment, target_length=256):
        if len(ecg_segment) == target_length:
            return ecg_segment
        return scipy.signal.resample(ecg_segment, target_length)

    def get_fixed_beat(self, ecg_sig, r_peaks, sample_number):
        peak_idx = np.where(r_peaks == sample_number)[0]

        if len(peak_idx) == 0 or peak_idx[0] == 0 or peak_idx[0] >= len(r_peaks) - 1:
            return None  # Skip if at the boundary

        peak_idx = peak_idx[0]
        start_idx = r_peaks[peak_idx - 1]
        end_idx = r_peaks[peak_idx + 1]

        ecg_beat = ecg_sig[start_idx:end_idx]
        return self.resample_ecg(ecg_beat, self.beat_length)

    # Uses SMOTE to generate synthetic samples for the minority classes.
    def apply_smote_balancing(self):
        print("Applying SMOTE for class balancing...")

        # Extract features (beats) and labels
        X = np.array([sig for _, sig, _ in self.labeled_events])
        y = np.array([lbl for _, _, lbl in self.labeled_events])

        # Flatten ECG beats to 1D (necessary for SMOTE)
        X_flattened = X.reshape(X.shape[0], -1)  # Shape: (num_samples, beat_length)

        # Apply SMOTE
        smote = SMOTE(sampling_strategy='auto', random_state=42, k_neighbors=5)
        X_resampled, y_resampled = smote.fit_resample(X_flattened, y)

        # Reshape back to original form
        X_resampled = X_resampled.reshape(X_resampled.shape[0], self.beat_length)

        # Update labeled events
        self.labeled_events = [(None, x, int(y)) for x, y in zip(X_resampled, y_resampled)]

        # Update class counts
        new_class_counts = {label: np.sum(y_resampled == idx) for label, idx in self.label_map.items()}
        print(f"New class distribution after SMOTE: {new_class_counts}")

    def __len__(self):
        return len(self.labeled_events)

    def __getitem__(self, idx):
        _, ecg_beat, label = self.labeled_events[idx]
        #ecg_beat = ecg_beat.unsqueeze(0).unsqueeze(1)  # Add channel dimension for CNN
        ecg_beat = ecg_beat.view(1, 256, 1)
        return ecg_beat, label

# %%
# --- Load Dataset Into Env ---
csv_file_dir = '/home/eveneiha/finn/workspace/ml/data/mitDB_AMII'
full_dataset = ECGDataset(csv_file_dir)
# Out:
# {'N': 0, 'S': 1, 'V': 2, 'F': 3, 'Q': 4}
# Initial class distribution: {'N': 89012, 'S': 2772, 'V': 7176, 'F': 802, 'Q': 6781}
# Applying SMOTE for class balancing...
# New class distribution after SMOTE: {'N': 89012, 'S': 89012, 'V': 89012, 'F': 89012, 'Q': 89012}

# %%
# plot to viz
# Select a random index from the dataset
sample_idx = np.random.randint(0, len(full_dataset))

# Fetch the sample
ecg_sample, label = full_dataset[sample_idx]

# Convert to numpy for plotting
ecg_sample_np = ecg_sample.squeeze().numpy()  # Remove channel dimension

# Plot the ECG beat
plt.figure(figsize=(8, 4))
plt.plot(ecg_sample_np, label=f"ECG Beat (Label: {label.item()})")
plt.title(f"ECG Beat from (Sample Index: {sample_idx})")
plt.xlabel("Time (samples)")
plt.ylabel("Normalized Amplitude")
plt.legend()
plt.grid(True)
plt.show()

# %%
class QuantizedTemporalBlock2d(nn.Module):
    def __init__(self, n_inputs, n_outputs, kernel_size, stride, dilation, dropout=0.2):
        super(QuantizedTemporalBlock2d, self).__init__()
        # Compute fixed, symmetric padding for the temporal dimension.
        fixed_padding = ((kernel_size - 1) * dilation) // 2

        # Input quantization identity
        #self.quant_inp = qnn.QuantIdentity(bit_width=8, act_quant=Int8ActPerTensorFloat)

        # Two quantized convolutional layers
        self.conv1 = qnn.QuantConv2d(
            n_inputs, n_outputs, kernel_size=(kernel_size, 1),
            stride=(stride, 1), padding=(fixed_padding, 0),
            dilation=(dilation, 1),
            weight_quant=Int8WeightPerTensorFloat,  # Quantizes weights to INT8
            input_quant=Int8ActPerTensorFloat,          # Quantizes activations to INT8
            weight_bit_width=8,
            act_bit_width=8,
            bias=False)
        self.conv2 = qnn.QuantConv2d(
            n_outputs, n_outputs, kernel_size=(kernel_size, 1),
            stride=(stride, 1), padding=(fixed_padding, 0),
            dilation=(dilation, 1),
            weight_quant=Int8WeightPerTensorFloat,  # Quantizes weights to INT8
            input_quant=Int8ActPerTensorFloat,          # Quantizes activations to INT8
            weight_bit_width=8,
            act_bit_width=8,
            bias=False)

        self.dropout = nn.Dropout(dropout)

        # QuantReLU after the conv branch (with quant tensor output)
        self.relu_after_conv = qnn.QuantReLU(return_quant_tensor=True)

        # **Uniform quantizers added on both branches:**
        #self.quant_main = qnn.QuantIdentity(bit_width=8, return_quant_tensor=True)
        #self.quant_res = qnn.QuantIdentity(bit_width=8, return_quant_tensor=True)

        # QuantReLU after the residual addition
        self.relu_after_residual = qnn.QuantReLU(return_quant_tensor=True)

        # Downsample (1×1 conv) for the skip connection if channel dimensions differ.
        if n_inputs != n_outputs:
            self.downsample = qnn.QuantConv2d(
                n_inputs, n_outputs, kernel_size=(1, 1),
                weight_quant=Int8WeightPerTensorFloat, 
                input_quant= Int8ActPerTensorFloat)
        else:
            self.downsample = None

    def forward(self, x):
        # Main branch:
        out = self.conv1(x)
        out = self.dropout(out)
        out = self.conv2(out)
        out = self.relu_after_conv(out).value  # unwrap quantized tensor after ReLU
        out = self.dropout(out)
        #out = self.quant_main(out).value         # apply uniform quantizer on main branch

        # Residual branch:
        #res = x if self.downsample is None else self.downsample(x)
        #res = self.quant_res(res).value          # apply uniform quantizer on residual branch

        # Add branches and apply final quantized activation.
        #out = out + res
        out = self.relu_after_residual(out).value

        return out





class QuantizedTCN2d(nn.Module):
    def __init__(self, num_inputs, num_outputs, num_channels, kernel_size, dropout, dilation_factor):
        super(QuantizedTCN2d, self).__init__()
        self.num_channels = num_channels
        self.temporal_blocks = nn.ModuleList()

        for i in range(len(num_channels)):
            dilation_size = dilation_factor ** i
            in_channels = num_inputs if i == 0 else num_channels[i - 1]
            out_channels = num_channels[i]
            # For conv2d, padding becomes (0, (kernel_size-1)*dilation)
            # padding = (kernel_size - 1) * dilation_size
            self.temporal_blocks.append(
                QuantizedTemporalBlock2d(in_channels, out_channels, kernel_size, stride=1,
                                           dilation=dilation_size, dropout=dropout))
        # NOT FINN COPAT: self.fc = qnn.QuantLinear(num_channels[-1], num_outputs, weight_quant=Int8WeightPerTensorFloat, input_quant=Int8ActPerTensorFloat, bias=False)
        
        self.fc = qnn.QuantConv2d(
            in_channels=num_channels[-1],
            out_channels=num_outputs,
            kernel_size=(1, 1),
            weight_quant=Int8WeightPerTensorFloat,
            input_quant=Int8ActPerTensorFloat,
            bias=False
        )
        
        self.inp_quant = qnn.QuantIdentity(bit_width=8, act_quant=Int8ActPerTensorFloat, return_quant_tensor=True)
        self.inp_quant2 = qnn.QuantIdentity(bit_width=8, act_quant=Int8ActPerTensorFloat, return_quant_tensor=True)

       
    def forward(self, x):
      x = self.inp_quant(x)
      for block in self.temporal_blocks:
          x = block(x)

      if hasattr(x, "value"):
          x = x.value

      # Average pooling to (1,1), then explicitly reshape (FINN compatible)
      # x shape: (N, C, L)
      #x = F.adaptive_avg_pool2d(x, (1,1))    # -> (N, C, 1)

      
      x = F.adaptive_avg_pool2d(x, (1, 1))
      # TODO: check quant optimizatiosn : x = self.inp_quant2(x)

      
         # -> (N, C)
     
    
      
      x = self.fc(x)
      x = x.reshape(x.size(0), -1)
    
      # Average pooling to (1,1), then explicitly reshape (FINN compatible)
      # x shape: (N, C, L)
    #   x = F.adaptive_avg_pool2d(x, (1,1))    # -> (N, C, 1)
    #   x = x.reshape(x.size(0), -1)  
      return x

# %%
# --- Model Config ---
## Create model

# --- Model Config ---
input_channels = 1      # 1 ECG channel
num_channels = [4, 8, 16]  # Number of channels at each block
output_channels = 5     # e.g., number of classes
kernel_size = 5
dilation_factor = 4
dropout = 0.074
lr = 0.008
batch_size = 256

# Instantiate the modified model
tcn = QuantizedTCN2d(input_channels, output_channels, num_channels, kernel_size, dropout, dilation_factor)

dummy_input = torch.randn(1, 1, 256, 1)  # Adjust dimensions if needed
tcn(dummy_input)

optimizer = optim.Adam(tcn.parameters(), lr=lr)

# Print model summary
summary(tcn, input_size=(1, 1, 256, 1))  # (batch_size, channels, sequence_length)
# Out:
# =============================================================================================================================
# Layer (type:depth-idx)                                                      Output Shape              Param #
# =============================================================================================================================
# QuantizedTCN2d                                                              [1, 5]                    --
# ├─QuantIdentity: 1-1                                                        [1, 1, 256, 1]            --
# │    └─ActQuantProxyFromInjector: 2-1                                       [1, 1, 256, 1]            --
# │    └─ActQuantProxyFromInjector: 2-2                                       [1, 1, 256, 1]            --
# │    │    └─FusedActivationQuantProxy: 3-1                                  [1, 1, 256, 1]            1
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─QuantIdentity: 1-3                                                        --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-4                                       --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-3                                  --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-5                                        [1, 4, 256, 1]            92
# │    │    └─QuantConv2d: 3-4                                                [1, 4, 256, 1]            21
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-13                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-6                                                --                        (recursive)
# │    │    └─Dropout: 3-7                                                    [1, 4, 256, 1]            --
# │    │    └─QuantConv2d: 3-8                                                [1, 4, 256, 1]            81
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-13                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-10                                               --                        (recursive)
# │    │    └─QuantReLU: 3-11                                                 [1, 4, 256, 1]            1
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-13                                       --                        (recursive)
# │    │    └─QuantReLU: 3-13                                                 --                        (recursive)
# │    │    └─Dropout: 3-14                                                   [1, 4, 256, 1]            --
# │    │    └─QuantReLU: 3-15                                                 [1, 4, 256, 1]            1
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-13                                       --                        (recursive)
# │    │    └─QuantReLU: 3-17                                                 --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-14                                       [1, 8, 256, 1]            364
# │    │    └─QuantConv2d: 3-18                                               [1, 8, 256, 1]            161
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-22                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-20                                               --                        (recursive)
# │    │    └─Dropout: 3-21                                                   [1, 8, 256, 1]            --
# │    │    └─QuantConv2d: 3-22                                               [1, 8, 256, 1]            321
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-22                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-24                                               --                        (recursive)
# │    │    └─QuantReLU: 3-25                                                 [1, 8, 256, 1]            1
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-22                                       --                        (recursive)
# │    │    └─QuantReLU: 3-27                                                 --                        (recursive)
# │    │    └─Dropout: 3-28                                                   [1, 8, 256, 1]            --
# │    │    └─QuantReLU: 3-29                                                 [1, 8, 256, 1]            1
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-22                                       --                        (recursive)
# │    │    └─QuantReLU: 3-31                                                 --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-23                                       [1, 16, 256, 1]           1,428
# │    │    └─QuantConv2d: 3-32                                               [1, 16, 256, 1]           641
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-31                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-34                                               --                        (recursive)
# │    │    └─Dropout: 3-35                                                   [1, 16, 256, 1]           --
# │    │    └─QuantConv2d: 3-36                                               [1, 16, 256, 1]           1,281
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-31                                       --                        (recursive)
# │    │    └─QuantConv2d: 3-38                                               --                        (recursive)
# │    │    └─QuantReLU: 3-39                                                 [1, 16, 256, 1]           1
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-31                                       --                        (recursive)
# │    │    └─QuantReLU: 3-41                                                 --                        (recursive)
# │    │    └─Dropout: 3-42                                                   [1, 16, 256, 1]           --
# │    │    └─QuantReLU: 3-43                                                 [1, 16, 256, 1]           1
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─ModuleList: 1-28                                                          --                        (recursive)
# │    └─QuantizedTemporalBlock2d: 2-31                                       --                        (recursive)
# │    │    └─QuantReLU: 3-45                                                 --                        (recursive)
# ├─QuantConv2d: 1-29                                                         [1, 5, 1, 1]              80
# │    └─ActQuantProxyFromInjector: 2-32                                      [1, 16, 1, 1]             --
# │    │    └─FusedActivationQuantProxy: 3-46                                 [1, 16, 1, 1]             1
# ├─QuantIdentity: 1-30                                                       --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-33                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-47                                 --                        (recursive)
# ├─QuantConv2d: 1-31                                                         --                        (recursive)
# │    └─ActQuantProxyFromInjector: 2-34                                      --                        (recursive)
# │    │    └─FusedActivationQuantProxy: 3-48                                 --                        (recursive)
# │    └─WeightQuantProxyFromInjector: 2-35                                   [5, 16, 1, 1]             --
# │    │    └─RescalingIntQuant: 3-49                                         [5, 16, 1, 1]             80
# │    └─ActQuantProxyFromInjector: 2-36                                      [1, 5, 1, 1]              --
# =============================================================================================================================
# Total params: 7,058
# Trainable params: 7,058
# Non-trainable params: 0
# Total mult-adds (M): 0
# =============================================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# =============================================================================================================================

# %%
# Split training, validation and testing

train_size = 0.7
val_size = 0.15
test_size = 0.15
loss_function = "label_smoothing"
# Stratified Data Split (with reduced size)
labels = [label.item() for _, label  in full_dataset]

# First, split train + temp (validation+test)
train_idx, temp_idx = train_test_split(
    list(range(len(full_dataset))), test_size=1 - train_size, stratify=labels, random_state=42)

# Get labels for second split (validation/test)
temp_labels = [labels[i] for i in temp_idx]

val_idx, test_idx = train_test_split(
    temp_idx, test_size=test_size/(test_size + val_size), stratify=temp_labels, random_state=42)

train_dataset = torch.utils.data.Subset(full_dataset, train_idx)
val_dataset = torch.utils.data.Subset(full_dataset, val_idx)
test_dataset = torch.utils.data.Subset(full_dataset, test_idx)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

test_labels = [label.item() for _, label in test_dataset]
print("Unique labels in test set:", set(test_labels))


# Calculate class weights
labels = []
for _,label in full_dataset:
  labels.append(label)
class_counts = torch.bincount(torch.stack(labels))
class_weights = 1.0 / (class_counts + 1e-7)
print("Class Weights: ", class_weights)


# --- Define Loss and Optimizer ---
# --- Select Loss Function ---
if loss_function == "cross_entropy":
    criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
elif loss_function == "label_smoothing":
    criterion = nn.CrossEntropyLoss(weight=class_weights.to(device), label_smoothing=0.1)
# Out:
# Unique labels in test set: {0, 1, 2, 3, 4}
# Class Weights:  tensor([1.1234e-05, 1.1234e-05, 1.1234e-05, 1.1234e-05, 1.1234e-05])

# %%
# ---------------------- Training Parameters ----------------------
num_epochs = 5  # number of training loops over the training dataset

# Lists for plotting Loss
training_losses = []
validation_losses = []


# --- Logging with wandB ---
wandb.init(project="tcn_experiments")

wandb.config.num_channels = num_channels
wandb.config.kernel_size = kernel_size
wandb.config.dropout = dropout
wandb.config.batch_size = batch_size
wandb.config.learning_rate = lr


# ---------------------- Training Loop ----------------------
tcn.train()
tcn.to(device) # Transfer model to GPU

running_loss = 0
running_correct = 0

for epoch in range(num_epochs):
    total_loss = 0
    batch_num = 0
    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        #Transfer data to GPU
        inputs = inputs.to(device)
        targets = targets.to(device)

        #Zero the gradients
        optimizer.zero_grad()
        # Forward pass
        outputs = tcn(inputs) # apply the TCN to the input
        # Calculate the loss
        loss = criterion(outputs, targets)
        # Backpropagation
        loss.backward()
        # Update weights
        optimizer.step()

        running_loss += loss.item() # update running loss
        _, predicted = torch.max(outputs, 1) # get the class prediction
        running_correct += (predicted == targets).sum().item() # update running correct

        # Log the progress
        if batch_idx % 100 == 0:
            print(f"Epoch: {epoch+1}/{num_epochs}, Batch: {batch_idx}/{len(train_dataloader)}, Loss: {loss.item():.4f}")
            # writer.add_scalar("Training loss", running_loss / 100 , epoch * len(train_dataloader) + batch_idx)
            # writer.add_scalar("Accuracy", running_correct / 100 , epoch * len(train_dataloader) + batch_idx)
            running_loss = 0.0
            running_correct = 0

        total_loss += loss.item() # update total loss
        batch_num+=1

    training_loss_avg = total_loss / batch_num
    training_losses.append(training_loss_avg) # append training loss to the list
   # writer.add_scalar("Loss/Train", training_loss_avg, epoch)

    train_loss = total_loss / len(train_dataloader)

    # --- Validation ---
    tcn.eval()  # ✅ Switch to evaluation mode
    total_loss_val = 0
    batch_num_val = 0
    correct, total = 0, 0  # ✅ Initialize accuracy tracking

    with torch.no_grad():
        for batch_idx_val, (inputs_val, targets_val) in enumerate(val_dataloader):
            inputs_val, targets_val = inputs_val.to(device), targets_val.to(device)

            # Forward pass
            outputs_val = tcn(inputs_val)

            # Calculate loss
            loss_val = criterion(outputs_val, targets_val)
            total_loss_val += loss_val.item()
            batch_num_val += 1


            _, predicted = torch.max(outputs_val, 1)
            correct += (predicted == targets_val).sum().item()
            total += targets_val.size(0)

    val_loss_avg = total_loss_val / batch_num_val
    validation_losses.append(val_loss_avg)
    val_acc = correct / total

    # 🔹 Print validation results
    print(f"📊 Epoch {epoch+1}/{num_epochs}: Train Loss={train_loss:.4f}, Val Loss={val_loss_avg:.4f}, Val Acc={val_acc:.4f}")

    tcn.train()
# Out:
# /home/eveneiha/.pyenv/versions/3.8.16/lib/python3.8/site-packages/torch/nn/modules/conv.py:454: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:294.)
#   return F.conv2d(input, weight, bias, self.stride,
# /home/eveneiha/.pyenv/versions/3.8.16/lib/python3.8/site-packages/brevitas/nn/quant_linear.py:69: UserWarning: Defining your `__torch_function__` as a plain method is deprecated and will be an error in future, please define it as a classmethod. (Triggered internally at ../torch/csrc/utils/python_arg_parser.cpp:294.)
#   output_tensor = linear(x, quant_weight, quant_bias)
# Epoch: 1/5, Batch: 0/1217, Loss: 1.6096
# Epoch: 1/5, Batch: 100/1217, Loss: 1.2355
# Epoch: 1/5, Batch: 200/1217, Loss: 0.8936
# Epoch: 1/5, Batch: 300/1217, Loss: 0.7281
# Epoch: 1/5, Batch: 400/1217, Loss: 0.7327
# Epoch: 1/5, Batch: 500/1217, Loss: 0.7239
# Epoch: 1/5, Batch: 600/1217, Loss: 0.6505
# Epoch: 1/5, Batch: 700/1217, Loss: 0.7140
# Epoch: 1/5, Batch: 800/1217, Loss: 0.6742
# Epoch: 1/5, Batch: 900/1217, Loss: 0.6376
# Epoch: 1/5, Batch: 1000/1217, Loss: 0.6620
# Epoch: 1/5, Batch: 1100/1217, Loss: 0.5963
# Epoch: 1/5, Batch: 1200/1217, Loss: 0.6224
# 📊 Epoch 1/5: Train Loss=0.7623, Val Loss=0.5933, Val Acc=0.9346
# Epoch: 2/5, Batch: 0/1217, Loss: 0.5940
# Epoch: 2/5, Batch: 100/1217, Loss: 0.6104
# Epoch: 2/5, Batch: 200/1217, Loss: 0.5924
# Epoch: 2/5, Batch: 300/1217, Loss: 0.6462
# Epoch: 2/5, Batch: 400/1217, Loss: 0.6065
# Epoch: 2/5, Batch: 500/1217, Loss: 0.5590

# %%
# --- Evaluation ---

tcn.eval()  # Set the model to evaluation mode

all_preds = []
all_targets = []

test_loss = 0
correct, total = 0, 0

with torch.no_grad():
    for inputs, targets in test_dataloader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = tcn(inputs)

        loss = criterion(outputs, targets)
        test_loss += loss.item()

        _, predicted = torch.max(outputs, 1) # get the class prediction
        correct += (predicted == targets).sum().item()
        total += targets.size(0)
        all_preds.extend(predicted.cpu().numpy()) # store predictions
        all_targets.extend(targets.cpu().numpy()) # store target labels

test_loss /= len(test_dataloader)
test_accuracy = correct / total

# wandb.run.summary["Final test_loss"] = test_loss
# wandb.run.summary["Finnal test_accuracy"] = test_accuracy
# wandb.finish()
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# Generate Confusion Matrix
cm = confusion_matrix(all_targets, all_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=AMII_CLASSES, yticklabels=AMII_CLASSES)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

print("Unique values in all_targets:", np.unique(all_targets))
print("Unique values in all_preds:", np.unique(all_preds))


# Generate classification report
print("Classification Report:\n", classification_report(all_targets, all_preds, target_names=AMII_CLASSES, zero_division=0))

# Plotting Loss
plt.figure(figsize=(10, 5))
plt.plot(range(num_epochs), training_losses, label='Training Loss')
plt.plot(range(num_epochs), validation_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Curve')
plt.legend()
plt.grid(True)
plt.show()

# --- Compute Total F1-Scores ---
macro_f1 = f1_score(all_targets, all_preds, average="macro")
weighted_f1 = f1_score(all_targets, all_preds, average="weighted")

print(f"📊 **Total Macro F1-Score**: {macro_f1:.4f}")
print(f"📊 **Total Weighted F1-Score**: {weighted_f1:.4f}")
# Out:
# Test Loss: 0.5379, Test Accuracy: 0.9565
# Unique values in all_targets: [0 1 2 3 4]
# Unique values in all_preds: [0 1 2 3 4]
# Classification Report:
#                precision    recall  f1-score   support
#
#            N       0.96      0.90      0.93     13352
#            S       0.94      0.96      0.95     13352
#            V       0.95      0.96      0.96     13352
#            F       0.94      0.97      0.96     13352
#            Q       0.99      0.98      0.98     13352
#
#     accuracy                           0.96     66760
#    macro avg       0.96      0.96      0.96     66760
# weighted avg       0.96      0.96      0.96     66760
# 📊 **Total Macro F1-Score**: 0.9563
# 📊 **Total Weighted F1-Score**: 0.9563

# %%
# --- Save model ---
torch.save({
    'model_state_dict': tcn.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),  # If you want to save optimizer state
}, '/home/eveneiha/finn/workspace/ml/intermidiate_models/tcn_model_v32.pth')

print("Training Done, model weights are saved")
# Out:
# Training Done, model weights are saved

# %%
# --- Restore old Models
# CPU:
checkpoint = torch.load('/home/eveneiha/finn/workspace/ml/intermidiate_models/tcn_model_v32.pth', map_location=torch.device('cpu'))


# GPU
# checkpoint = torch.load('/content/drive/MyDrive/Master/tcn_model_v32.pth')
tcn.load_state_dict(checkpoint['model_state_dict'], strict=False)
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])  # If needed
tcn.eval()
# Out:
# /tmp/ipykernel_126446/1219979239.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('/home/eveneiha/finn/workspace/ml/intermidiate_models/tcn_model_v32.pth', map_location=torch.device('cpu'))
# QuantizedTCN2d(
#   (temporal_blocks): ModuleList(
#     (0): QuantizedTemporalBlock2d(
#       (conv1): QuantConv1d(
#         1, 4, kernel_size=(5,), stride=(1,), padding=(2,), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (conv2): QuantConv1d(
#         4, 4, kernel_size=(5,), stride=(1,), padding=(2,), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (dropout): Dropout(p=0.074, inplace=False)
#       (relu_after_conv): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (relu_after_residual): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (downsample): QuantConv1d(
#         1, 4, kernel_size=(1,), stride=(1,)
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#     )
#     (1): QuantizedTemporalBlock2d(
#       (conv1): QuantConv1d(
#         4, 8, kernel_size=(5,), stride=(1,), padding=(8,), dilation=(4,), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (conv2): QuantConv1d(
#         8, 8, kernel_size=(5,), stride=(1,), padding=(8,), dilation=(4,), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (dropout): Dropout(p=0.074, inplace=False)
#       (relu_after_conv): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (relu_after_residual): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (downsample): QuantConv1d(
#         4, 8, kernel_size=(1,), stride=(1,)
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#     )
#     (2): QuantizedTemporalBlock2d(
#       (conv1): QuantConv1d(
#         8, 16, kernel_size=(5,), stride=(1,), padding=(32,), dilation=(16,), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (conv2): QuantConv1d(
#         16, 16, kernel_size=(5,), stride=(1,), padding=(32,), dilation=(16,), bias=False
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): Identity()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#       (dropout): Dropout(p=0.074, inplace=False)
#       (relu_after_conv): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (relu_after_residual): QuantReLU(
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (act_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (fused_activation_quant_proxy): FusedActivationQuantProxy(
#             (activation_impl): ReLU()
#             (tensor_quant): RescalingIntQuant(
#               (int_quant): IntQuant(
#                 (float_to_int_impl): RoundSte()
#                 (tensor_clamp_impl): TensorClamp()
#                 (delay_wrapper): DelayWrapper(
#                   (delay_impl): _NoDelay()
#                 )
#                 (input_view_impl): Identity()
#               )
#               (scaling_impl): ParameterFromRuntimeStatsScaling(
#                 (stats_input_view_shape_impl): OverTensorView()
#                 (stats): _Stats(
#                   (stats_impl): AbsPercentile()
#                 )
#                 (restrict_scaling_impl): FloatRestrictValue()
#                 (restrict_scaling): _RestrictValue(
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (clamp_scaling): _ClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                 )
#                 (restrict_inplace_preprocess): Identity()
#                 (restrict_preprocess): Identity()
#               )
#               (int_scaling_impl): IntScaling()
#               (zero_point_impl): ZeroZeroPoint(
#                 (zero_point): StatelessBuffer()
#               )
#               (msb_clamp_bit_width_impl): BitWidthConst(
#                 (bit_width): StatelessBuffer()
#               )
#             )
#           )
#         )
#       )
#       (downsample): QuantConv1d(
#         8, 16, kernel_size=(1,), stride=(1,)
#         (input_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (output_quant): ActQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#         (weight_quant): WeightQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#           (tensor_quant): RescalingIntQuant(
#             (int_quant): IntQuant(
#               (float_to_int_impl): RoundSte()
#               (tensor_clamp_impl): TensorClampSte()
#               (delay_wrapper): DelayWrapper(
#                 (delay_impl): _NoDelay()
#               )
#               (input_view_impl): Identity()
#             )
#             (scaling_impl): StatsFromParameterScaling(
#               (parameter_list_stats): _ParameterListStats(
#                 (first_tracked_param): _ViewParameterWrapper(
#                   (view_shape_impl): OverTensorView()
#                 )
#                 (stats): _Stats(
#                   (stats_impl): AbsMax()
#                 )
#               )
#               (stats_scaling_impl): _StatsScaling(
#                 (affine_rescaling): Identity()
#                 (restrict_clamp_scaling): _RestrictClampValue(
#                   (clamp_min_ste): ScalarClampMinSte()
#                   (restrict_value_impl): FloatRestrictValue()
#                 )
#                 (restrict_scaling_pre): Identity()
#                 (restrict_scaling_impl): FloatRestrictValue()
#               )
#             )
#             (int_scaling_impl): IntScaling()
#             (zero_point_impl): ZeroZeroPoint(
#               (zero_point): StatelessBuffer()
#             )
#             (msb_clamp_bit_width_impl): BitWidthConst(
#               (bit_width): StatelessBuffer()
#             )
#           )
#         )
#         (bias_quant): BiasQuantProxyFromInjector(
#           (_zero_hw_sentinel): StatelessBuffer()
#         )
#       )
#     )
#   )
#   (quant_inp): QuantIdentity(
#     (input_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#     (act_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#       (fused_activation_quant_proxy): FusedActivationQuantProxy(
#         (activation_impl): Identity()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClamp()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#             (input_view_impl): Identity()
#           )
#           (scaling_impl): ParameterFromRuntimeStatsScaling(
#             (stats_input_view_shape_impl): OverTensorView()
#             (stats): _Stats(
#               (stats_impl): AbsPercentile()
#             )
#             (restrict_scaling_impl): FloatRestrictValue()
#             (restrict_scaling): _RestrictValue(
#               (restrict_value_impl): FloatRestrictValue()
#             )
#             (clamp_scaling): _ClampValue(
#               (clamp_min_ste): ScalarClampMinSte()
#             )
#             (restrict_inplace_preprocess): Identity()
#             (restrict_preprocess): Identity()
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#     )
#   )
#   (fc): QuantLinear(
#     in_features=16, out_features=5, bias=False
#     (input_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#       (fused_activation_quant_proxy): FusedActivationQuantProxy(
#         (activation_impl): Identity()
#         (tensor_quant): RescalingIntQuant(
#           (int_quant): IntQuant(
#             (float_to_int_impl): RoundSte()
#             (tensor_clamp_impl): TensorClamp()
#             (delay_wrapper): DelayWrapper(
#               (delay_impl): _NoDelay()
#             )
#             (input_view_impl): Identity()
#           )
#           (scaling_impl): ParameterFromRuntimeStatsScaling(
#             (stats_input_view_shape_impl): OverTensorView()
#             (stats): _Stats(
#               (stats_impl): AbsPercentile()
#             )
#             (restrict_scaling_impl): FloatRestrictValue()
#             (restrict_scaling): _RestrictValue(
#               (restrict_value_impl): FloatRestrictValue()
#             )
#             (clamp_scaling): _ClampValue(
#               (clamp_min_ste): ScalarClampMinSte()
#             )
#             (restrict_inplace_preprocess): Identity()
#             (restrict_preprocess): Identity()
#           )
#           (int_scaling_impl): IntScaling()
#           (zero_point_impl): ZeroZeroPoint(
#             (zero_point): StatelessBuffer()
#           )
#           (msb_clamp_bit_width_impl): BitWidthConst(
#             (bit_width): StatelessBuffer()
#           )
#         )
#       )
#     )
#     (output_quant): ActQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#     (weight_quant): WeightQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#       (tensor_quant): RescalingIntQuant(
#         (int_quant): IntQuant(
#           (float_to_int_impl): RoundSte()
#           (tensor_clamp_impl): TensorClampSte()
#           (delay_wrapper): DelayWrapper(
#             (delay_impl): _NoDelay()
#           )
#           (input_view_impl): Identity()
#         )
#         (scaling_impl): StatsFromParameterScaling(
#           (parameter_list_stats): _ParameterListStats(
#             (first_tracked_param): _ViewParameterWrapper(
#               (view_shape_impl): OverTensorView()
#             )
#             (stats): _Stats(
#               (stats_impl): AbsMax()
#             )
#           )
#           (stats_scaling_impl): _StatsScaling(
#             (affine_rescaling): Identity()
#             (restrict_clamp_scaling): _RestrictClampValue(
#               (clamp_min_ste): ScalarClampMinSte()
#               (restrict_value_impl): FloatRestrictValue()
#             )
#             (restrict_scaling_pre): Identity()
#             (restrict_scaling_impl): FloatRestrictValue()
#           )
#         )
#         (int_scaling_impl): IntScaling()
#         (zero_point_impl): ZeroZeroPoint(
#           (zero_point): StatelessBuffer()
#         )
#         (msb_clamp_bit_width_impl): BitWidthConst(
#           (bit_width): StatelessBuffer()
#         )
#       )
#     )
#     (bias_quant): BiasQuantProxyFromInjector(
#       (_zero_hw_sentinel): StatelessBuffer()
#     )
#   )
# )

# %%
from brevitas.export import export_qonnx

# scale_factor = 9.607829269953072e7  # example value from your Mul node

# with torch.no_grad():
#     # multiply final FC weights
#     tcn.fc.weight *= scale_factor
#     # if you had a bias and needed to fold it too:
#     # model.fc.bias *= scale_factor

tcn.eval()
tcn = tcn.to(device)
# Create quantizer
dummy_input = torch.randn(1, 1, 256, 1).to(device)

export_qonnx(tcn, dummy_input, export_path='/home/eveneiha/finn/workspace/finn/onnx/tcn_v33.onnx', opset_version=9)
# Out:
# ir_version: 4
# producer_name: "pytorch"
# producer_version: "2.4.1"
# graph {
#   node {
#     input: "x.721"
#     input: "/inp_quant/act_quant/export_handler/Constant_1_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/inp_quant/act_quant/export_handler/Quant_output_0"
#     name: "/inp_quant/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/inp_quant/act_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/conv1/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/conv1/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/conv1/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/conv1/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/conv1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/conv1/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.0/conv1/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.0/conv1/Conv_output_0"
#     name: "/temporal_blocks.0/conv1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 2
#       ints: 0
#       ints: 2
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.0/conv1/Conv_output_0"
#     input: "/temporal_blocks.0/conv2/input_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/conv2/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/conv2/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/conv2/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.0/conv2/weight_quant/export_handler/Constant_1_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/conv2/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/conv2/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/conv2/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.0/conv2/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.0/conv2/Conv_output_0"
#     name: "/temporal_blocks.0/conv2/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 2
#       ints: 0
#       ints: 2
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.0/conv2/Conv_output_0"
#     output: "/temporal_blocks.0/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.0/relu_after_conv/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.0/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.0/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.0/relu_after_residual/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.0/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.1/conv1/input_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/conv1/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/conv1/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/conv1/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.1/conv1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/conv1/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/conv1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/conv1/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.1/conv1/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.1/conv1/Conv_output_0"
#     name: "/temporal_blocks.1/conv1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 4
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 8
#       ints: 0
#       ints: 8
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.1/conv1/Conv_output_0"
#     input: "/temporal_blocks.1/conv2/input_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/conv2/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/conv2/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/conv2/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.1/conv2/weight_quant/export_handler/Constant_1_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/conv2/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/conv2/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/conv2/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.1/conv2/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.1/conv2/Conv_output_0"
#     name: "/temporal_blocks.1/conv2/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 4
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 8
#       ints: 0
#       ints: 8
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.1/conv2/Conv_output_0"
#     output: "/temporal_blocks.1/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.1/relu_after_conv/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.1/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.1/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.1/relu_after_residual/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.1/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.2/conv1/input_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/conv1/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/conv1/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/conv1/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.2/conv1/weight_quant/export_handler/Constant_1_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/conv1/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/conv1/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/conv1/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.2/conv1/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.2/conv1/Conv_output_0"
#     name: "/temporal_blocks.2/conv1/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 16
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 32
#       ints: 0
#       ints: 32
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.2/conv1/Conv_output_0"
#     input: "/temporal_blocks.2/conv2/input_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/conv2/input_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/conv2/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/conv2/weight_quant/export_handler/Constant_output_0"
#     input: "/temporal_blocks.2/conv2/weight_quant/export_handler/Constant_1_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/conv2/weight_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/conv2/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/conv2/input_quant/export_handler/Quant_output_0"
#     input: "/temporal_blocks.2/conv2/weight_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.2/conv2/Conv_output_0"
#     name: "/temporal_blocks.2/conv2/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 16
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 32
#       ints: 0
#       ints: 32
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/temporal_blocks.2/conv2/Conv_output_0"
#     output: "/temporal_blocks.2/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.2/relu_after_conv/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.2/relu_after_conv/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     output: "/temporal_blocks.2/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     name: "/temporal_blocks.2/relu_after_residual/act_quant/activation_impl/Relu"
#     op_type: "Relu"
#   }
#   node {
#     input: "/temporal_blocks.2/relu_after_residual/act_quant/activation_impl/Relu_output_0"
#     input: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     name: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 0
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     output: "/GlobalAveragePool_output_0"
#     name: "/GlobalAveragePool"
#     op_type: "GlobalAveragePool"
#   }
#   node {
#     input: "/GlobalAveragePool_output_0"
#     input: "/fc/input_quant/export_handler/Constant_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/fc/input_quant/export_handler/Quant_output_0"
#     name: "/fc/input_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 0
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/fc/weight_quant/export_handler/Constant_output_0"
#     input: "/fc/weight_quant/export_handler/Constant_1_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     input: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     output: "/fc/weight_quant/export_handler/Quant_output_0"
#     name: "/fc/weight_quant/export_handler/Quant"
#     op_type: "Quant"
#     attribute {
#       name: "narrow"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "rounding_mode"
#       s: "ROUND"
#       type: STRING
#     }
#     attribute {
#       name: "signed"
#       i: 1
#       type: INT
#     }
#     domain: "onnx.brevitas"
#   }
#   node {
#     input: "/fc/input_quant/export_handler/Quant_output_0"
#     input: "/fc/weight_quant/export_handler/Quant_output_0"
#     output: "/fc/Conv_output_0"
#     name: "/fc/Conv"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "/fc/Conv_output_0"
#     input: "/Constant_output_0"
#     output: "100"
#     name: "/Reshape"
#     op_type: "Reshape"
#   }
#   name: "main_graph"
#   initializer {
#     data_type: 1
#     name: "/inp_quant/act_quant/export_handler/Constant_output_0"
#     raw_data: "\000\000\000A"
#   }
#   initializer {
#     data_type: 1
#     name: "/inp_quant/act_quant/export_handler/Constant_1_output_0"
#     raw_data: "\2679\246<"
#   }
#   initializer {
#     data_type: 1
#     name: "/inp_quant/act_quant/export_handler/Constant_2_output_0"
#     raw_data: "\000\000\000\000"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv1/input_quant/export_handler/Constant_output_0"
#     raw_data: "D\355\244<"
#   }
#   initializer {
#     dims: 4
#     dims: 1
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.0/conv1/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\307\331\363\275A!,<\254\201\345\275z\234\312>\251\266\343>b\017>>\237U\336>A!,\276\213\223S>R\030\265\276\213\223\323\276\014q\017>\251\266\343\276\031\235\226\275p;E>\213\223S\276\373y\206\276\324\005{\276\221)\327=\333\233~\276"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv1/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "\254\201e;"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv2/input_quant/export_handler/Constant_output_0"
#     raw_data: "\224\323c<"
#   }
#   initializer {
#     dims: 4
#     dims: 4
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.0/conv2/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\216w\364<\\\212\276\275+\026f<fSI<p\034T\276\210V@>\214\376\026>\327%9\276*\235\010>\334Fm=\027\204P>4f\023>\222\037K>\214\376\026=\252Y7>p\034T>\027\204\320=\\\212\276=\003\362:\275\357_%\275xl\201<\327%9\276\353\267N>4f\223=\346\017\370=\257\001\016>>/\036=xl\001>\252Y7>H\370\250\275\240\220\254<*\235\010\276\214\376\026>\003\362\272<\230@\377\275xl\201=p\034\324\275\003\362:\276\371(\260=\264\"\302=+\026\346\272\240\220,\276\234\350U>\341\356C\276\310\264\327<\2025\014\276\2025\214\275\333\315\017<~\2155\276\321\004\205=+\026f=4f\023\276\027\204P\275\204\256\351=\240\220,>\033,\'>+\026\346\273\214\376\026=\027\204P>`2\025>\240\220,\275\240\220,<\357_%>\000\000\000\200+\026f<\264\"B\276\321\004\005\276fSI\275z\345\336\275+\026f\275%\3651>\276\353L\276\240\220\254=\377Id\276\333\315\017>R\301\263\275fSI\276\240\220\254\273\r\273E>\222\037K\276"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/conv2/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "+\026\346:"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     raw_data: "\255z\211;"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     raw_data: "5w\224;"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/conv1/input_quant/export_handler/Constant_output_0"
#     raw_data: "\276\342\023<"
#   }
#   initializer {
#     dims: 8
#     dims: 4
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.1/conv1/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\250\365\272\275\251\320\017\276\276\357\314\275>]\267=SW\311<\324\237\010\276t\004\016>\024i\223=\024i\223=)c\245=\376n\001=\376\270W=HZ@>>]7\276hQ[\276\250\365:>SWI<\363\226#\276\323\3043=^TR\276\023\216>\276(\255\373\275\036\213G>^/\'>T2\036=\251\320\017>=\202b>}K\355\275\323\351\336=~&\302\275~&B\276\336\301<\276\t\2215\276)c%>\250\032\346\273~&B\276\376\270W>\376\270W=\250\032f=\236\3701\276\263\362C\276~&B==\202\342\275(\255\373=\263\362C>\376\270W\275\235\035]>\323\351^=I5\025>\250\032f\274\223\373\250=R|t=\323\304\263\275\376n\001\2764;\003\276\210#K>\263\362C>>8\214\275\376\270W=\223 T>\t\2215\276\376\270W\275\010\266`\276\276\312\241=SW\311\274\376\223\254=\223\373(\276\250\032f=\010\266`\276~&B=\024i\023\276~\001\027\275\336\234\021>R|\364<\024i\023\276(\210P>R|\364\274\036f\034\276\376n\001>\276\312\241=)c%\275i\007\005\276t\004\016>\251\320\017=\250\032f\2753\205Y>\350\343\360\275~\001\027\276t\004\016\276s)9>s)9\276\376\223\254\273\036f\034\276I5\025>\250\365\272\274\310\354U>\323\304\263=\236\323\006\276\336\301<>hQ\333\275\264\315\030\276T2\036\276\023\263\351\275\250\365\272\274\023\216>\2763\205Y>\376\270\327=\010\266`\276\036f\034\276\276\357\314\275(\255\373\275\036\213G\276\323\351\336\275\310\354U>\250\365\272<\251\320\017\274i\007\205\275\324\237\010>\336\301<\276\250\365\272\275\376\223,\274T2\236=}K\355\275\010\266`>4;\003>^TR>i,0\276\023\216\276=\310\354U\276\251\320\017>sNd\276\251\320\017>\323\304\263\275i,\260=i\007\005>>8\014\276\250\032\346:i\007\005\276\310\354U>SWI<(\255{=>]\267\275\211\376\037\276(\210P\276\223 \324\275\222E\377=\323\351^=\251\320\017\275HZ@\276T2\236\275\376\223,=\250\365\272<>]\267=\263\362C>\236\323\006\276\236\3701>\350\276E>=\202b\276\276\357\314=\250\032\346:"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/conv1/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "\250\032\346:"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/conv2/input_quant/export_handler/Constant_output_0"
#     raw_data: "\007\300\236;"
#   }
#   initializer {
#     dims: 8
#     dims: 8
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.1/conv2/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\353K`=\351\310y=\355\000\321\275\363\273\016>\352\257\364\274ra\226\275sH\221\275\352\257t\273\363\242\t>\361\037#<j\n\355=\356\265\301\274\353K`<\362\324\023\275\362\355\030\275\361\037#<\262\300\034>\352\257t=\361\037#<\362\355\030\275\363\273\016<\361\037\243\2731M\037\276m[\311=\352\257t;q\223 >\352\226o=\356\316\306\275\357\234<=\364\211\204\274\363\273\216\2752\033\025\276\361\037#\274\352}\352\275\361\037#\273\362\355\230\274\3618(\275\363\242\t=\352\257\364<q\223 >\355\347K\274\355\347\313\274\361\006\236\275t\375\201\275\361\006\236=\353K`=\361\037\243:\361\037#;\351\310\371\275rz\233\275p\336\257\275\357\2037=\355\347K\274q\223 >\363\242\211=\352\257t=mt\316\275\352\257t<o\020\272=m[\311=\360Q-=\362\355\030\276\361\006\036\275\356\316F=\263u\r>\363\273\016=\357\234\274=\352\257t\274\357\203\267\275\361\037\243\274m[\311=ra\026\276sH\221\275\363\273\216<\351\310y\275\362\355\030\275\352\257t\273s/\214\275iU\374\275\352\257t=\355\347\313\273\352\257\364=\352\257\364<\263u\r\276\355\347\313\274\363\273\216<\361\006\036=m[\311\275\352}\352\274\356\316\306=\263\216\022>\361\037\243\275\352\257t\275\357\2037<4\320\005>j\n\355\275\360Q-=\352\257t\273\363\242\t\275\362\355\230<\352\257t;\357\2037<\363\242\t\276\355\347\313\273\363\273\216\275iU\374\275q\223\240\275rz\233\275\364\211\004>\354\031V\275\355\000\321\275\356\316\306\275\352\257\364\275\361\037#\273\262\300\034>\3542\333=\356\265A\275\357\234\274\275\355\347\313\273\362\355\030=n)\277=\362\355\230=sH\021>\363\242\t>p\305\252=\354\031\326<\362\355\030\275\361\037\243:q\223 \276\263\\\010\276k\361\347\275l\277\335\27524\032>\361\006\036\276\352}\352<nB\304\275\363\273\016<\362\324\023>\351\341\376=\362\324\223=\356\265A=\364\211\004\275\357\203\267\275\263\216\022\276t\026\207=\353K`=\364\211\004\275mt\316=rz\233=j#\362\275\263\\\010>\356\316F\275n)\277\275t\375\201=\352}\352<s/\014>\353K`=\262\247\027>\364\211\004\276\363\242\t\276\357\2037<m[\311\275\357\234\274=mt\316\275i<\367=\352}j=t\026\007\276k\330\342\275\356\316F\275mt\316=k\330\342=\363\273\016\276\357\203\267\275\364\211\004\276\362\324\023\275\357\234<=ra\226=\357\2037\275\352}j=\354\031\326\275rz\233\275\356\265A\275\356\316F=q\223 \276sH\221=\354\031\326\275t\375\201\275q\223 >k\330\342=\360Q\255\275n)\277=mt\316\275\353de=\356\316\306=\354\031\326\275\361\006\036\275\356\316\306=\363\273\016\275rz\233\275\356\265\301\274m\215\323\275\363\242\t>\353de\275s/\214\275\364\211\004\276\363\273\016\276i<\367\275\364\211\004=2\033\025\276n)\277=2\033\025>\352}\352<iU\374\275t\375\001>\3542\333\275\361\006\236=\355\347\313\275o\367\264\275\361\037#=\351\310\371\275i<\367=\356\265\301\2754\320\005>\361\037\243;\351\341\376\274\361\006\036>\353de\275s/\214=\352\257\364\275\356\316F=\363\242\t>\354\031V\275\356\265A\275\363\273\016>\352}\352=\363\273\216=\351\341\376=\361\037\243;\352\257\364\273\361\037\243=n)\277=\261\331!>j\n\355=\352\257t\273p\336\257\275q\223 >\263\216\022>\363\273\016>\351\310y\275\352}j\275\352\257\364;\356\316\306\275\362\355\030=\363\242\t\276m[\311\275p\336\257=\364\211\204\274\363\242\t>\361\006\036\276\361\037\243<\362\324\023\276\262\247\027>j#\362=\355\347K=\3618(=\363\242\t\276\264C\003\276\364\211\204=\360j2\275\352}\352=2\033\025\276j#\362\275l\246\330\275\352\257\364;\363\273\016\275\356\316\306\275\353K\340=sH\021>\363\242\t=o\020\272\275\353K\340\274mt\316=\354\031\326\274\3618\250\275nB\304\275\356\265A\275\352\257t\273\361\037#\275\352}j=\363\242\t\275p\336\257=\3618(\275\354\031V\275\360j2\275rz\033>k\361\347\275p\336\257=\352\257t;\355\347\313\273\353K\340\274\263\\\010>\360j2\275\363\273\216\274\000\000\000\200t\375\001>\361\006\236\275\261\331!>\263\\\010\276\363\273\016\275m\215\323=t\375\201\275\363\273\016>t\375\001\276\351\341\376\274\362\324\023\2763\351\n\276\352\257t\274\3542\333=\355\000Q\275\357\234<\275"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/conv2/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "\361\037\243:"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     raw_data: "Q\326\205:"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     raw_data: "X\210\220:"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/conv1/input_quant/export_handler/Constant_output_0"
#     raw_data: "\320\367\017;"
#   }
#   initializer {
#     dims: 16
#     dims: 8
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.2/conv1/weight_quant/export_handler/Constant_output_0"
#     raw_data: "[F\311\275\315?-=\032\233\245\275\310 \014>\214\224\t\275\214\224\211\275\315?\255=J\260\034>\323\227\027\276N\226\364\273\345f\r>DX2=\227\322K\2742\211\274\275h\366\035\276-j\233=\023\n\362\275\344-\304\275\330}o\275s4`=\016\353\320=\310 \214=\374\033[\275\3675\003\276\234\361\354= \272\306=h\366\235\275\177\344\264=z\305\023\276\205\003\326<\025|\204\274\256\300\342\275\244\202 >\227\322\313\275\025|\204<\330}o=\266Q\226=N\226t<%\331\347=\023\n\362\275h\366\035\276\244\202\240\275\003\255\016\276\337\016\243\272h\366\035>\003\255\016>N\226t;\266Q\226=N\226t;N\226\364\275N\226\364;\221\263\252=\003\255\016\275\025|\204\274\274\251\000\276\345f\r>\010\314\257=\251\241A=\310 \214\275\000\000\000\000\337\016\243\274?9\221\275\214\224\t\275<\307\376\274\310 \014\276\212\"\367\275\227\322\313;\266Q\226=s4\340\274\251\241\301\275s4\340=N\226t<s4`=\251\241A=\251\241A\275\337\016#\273\361\335\230\275\003\255\216=\305\256y\275?9\021>\205\003\326=\310 \214\275\032\233\245\275\361\335\230\274V\'(\275\025|\204\275\244\202 \2762\211\274=\337\016#\273\244\202 >N\226\364\273N\226\364<-j\033>\256\300\342\275\177\344\264\275\266Q\226\275\251\241\301\275\305\256y=\206<\037>\214\224\t=N\226t\274\344-\304=\025|\004>\227\322\313\273\273p7<\374\033\333\275\251\241A=\361\335\230\274aej=2\211<\275\252\332\n>\305\256\371\275N\226t=\227\322K=%\331\347\275N\226t\274\251\241\301=\252\332\n\276%\331\347=\310 \214\275\310 \214=\221\263\252=\025|\204=V\'\250\275\025|\004=%\331\347\275\000\000\000\200N\226t<\221\263\252\275\025|\004\275\266Q\226\275-j\033><\307\376<\206<\037\276\310 \014\276s4`<Q\010\007>\244\202 \276h\366\035\276?9\021\276\003\255\016<\332\357\001\2767\250\335=\003\255\016>\025|\204=\001;\374\275%\331\347=[F\311=<\307\376<ae\352=7\250\335=\337\016\243\273\025|\204<N\226t\273\273p\267=\337\016\243:\337\016\243\275m\025\277\2753\302\005>\273p7<\361\335\230\275\315?\255\274\016\353P=aej=\330}o\275\345f\r\276\337\016\243\274N\226t\274\315?\255=\273p\267\275\352L\345=z\305\223\275\352L\345=\017$\032\276%\331\347\275nN\010\276ae\352<<\307\376\275s4`<\332\357\001\276\344-\304\275\003\255\216<\244\202 >V\'\250=\230\013\025\276\332\357\001>\352Le=h\366\235\275[F\311=\230\013\025>Q\010\207\275\023\n\362=\003\255\016\275\227\322K\2752\211\274\275\3675\003\276z\305\023\275\315?\255<\205\003\326<\361\335\230\274N\226\364;s4`\275ae\352\274\310 \214\275\230\013\025><\307\376<\273p7\275\337\016\243:\003\255\016=\361\335\030>N\226t\274\003\255\216\275\337\016#<N\226t\273s4`\274\251\241\301=z\305\023> \272F=\315?-=s4`<z\305\223=V\'(=z\305\023\276\177\344\264=\227\322\313;\227\322\313=\374\033\333\275\003\255\016\275V\'\250\275\214\224\t\275z\305\023=2\211<=\227\322\313<\274\251\000>N\226\364\2733\302\005>\025|\204= \272\306=\221\263\252=Q\010\207=\177\344\264=\266Q\026\276\003\255\016<\332\357\201\275\305\256y\275\374\033\333=\003\255\216\275\205\003\326\275DX\262\275\266Q\026\276\361\335\230<\332\357\201\275\177\344\264=N\226\364\274<\307\376<\251\241\301=\352L\345=\310 \014>h\366\035>!\363\017\276s4\340\275\352L\345=s4`=\252\332\n\276?9\221=\205\003\326\275%\331\347\2753\302\005\276%\331\347=\025|\204\274\010\314\257=\301\310!>\227\322\313\273\361\335\030>\305\256y=\310 \214=DX2= \272F=\300\217\330=\337\016#=\214\224\t>h\366\235=ae\352<[F\311=\214\224\211=\227\322\313=\016\353P=h\366\035=DX2\275s4\340\275\212\"\367=\315?-\275\361\335\030\276\016\353\320=h\366\235\275\025|\204\275\025|\004>\361\335\030\275ae\352\275s4`<\273p\267=\337\016\243\275\322^\316=\352L\345=\025|\004\276\016\353\320=<\307~=DX2\275aej\275\032\233\245\275\323\227\027\276\337\016#\274ae\352\274\301\310!>?9\221=\273p7<\361\335\030\276\337\016\243:s4`<\016\353\320=DX\262=ae\352\274!\363\017\276\252\332\n\276<\307~=\374\033[=\305\256\371\2757\250\335\275\337\016\243\275\361\335\030\276\361\335\230=J\260\034>\230\013\025\276\025|\204<\366\374\271\275\023\n\362=\227\322\313;\323\227\027\276-j\233=\234\361\354=\323\227\027\276\352Le= \272F\275\025|\004\276[F\311\275\206<\037\2 ...
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/conv1/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "\337\016\243:"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/conv2/input_quant/export_handler/Constant_output_0"
#     raw_data: "emY:"
#   }
#   initializer {
#     dims: 16
#     dims: 16
#     dims: 5
#     dims: 1
#     data_type: 1
#     name: "/temporal_blocks.2/conv2/weight_quant/export_handler/Constant_output_0"
#     raw_data: "a\362\333\275\214\303f\275\214\303f\274\305/u<\032\353\311\2748:\220\274\305H\264=\033\004\t=\267\2550\275\277\007\222=\232^j\275w\347\300=\033\004\211\274\215\334%\275p\246\236\274\324\343\267\275\305/u\2757!\321\2748:\220;)\206M\275\341e\374\274\315\242\225=\377\315\201\275\005\366\344\275E\274T=\377\315\001<\214\303f;\267\2550=\033\004\211=\276\356\322\275p\215\337<\377\315\001\275\250\371m=\032\353\311;SWX\275\260l\216=\305/u<>{\262\275~(\343=\251\022\255;[\261\271\275\377\315\201=Tp\027=a\362[\275\005\366\344\275\223\035\310=p\215_=[\261\271=a\362[\2758:\020<\205\202\304\275\024\252\247\275\214\303\346;a\362\333\275\006\017\244=\376\264\302=\305/u=p\246\236<\242\321\212=p\246\036\2758:\220\273E\274\324\275\033\004\211\275\214\303\346:\360\031?\275\377\315\001=\315\242\225=Tp\227=7!\321<\314\211\326\275~A\242\275\260S\317\275p\246\236<\024\252\247\275Tp\027=\341e\374\2748:\220=\214\303f=8:\020=7!Q=\214\303f;\367s\240\275\250\371\355\274a\362[\275~A\242=\214\303f:E\274T=L\026\266=\277\007\222=E\274T\275\024\252\247\275\242\270\313=\377\315\001<~(c=\342~\273=\360\031?\275\333=\231\275\033\004\211=\267\255\260\275\032\353\311<\006\017\244\275\376\264\302<[\261\271=\006\017\244\275~A\242\275\032\353I<\305H4\275Tp\027\275\314\211\326\275\377\315\001\274\250\371m\275\214\303f\275\232^j\275\032\353\311\274\214\303\346;\342~;=\"E\253=\341e\374<\251\022-\274\214\303f;\323\312x=SW\330\275\342~;\274\332$\332\275\324\343\267\275\267\2550\275\214\303f;\000\000\000\200\324\3437=\"E\253\275\351\277\335\275F\325\023=\014P\306\2758:\220\273\377\315\001=\232^j=\032\353\311;SWX<~(c=p\215_=\260S\317\275b\013\033=\215\334\245=\250\371m=\377\315\201\275E\274\324\275Tp\227\275\024\252\247\275~(\343\275\251\022-\274~(\343\275\206\233\203\275\251\022\255\274~A\242=\014PF=\305H\264\274\033\004\211=\305/u=\205\202\304=\214\303f\275\251\022\255<Tp\227\275\342~;<SWX<\377\315\201<>{\262=\341e|\275\377\315\201\274p\246\236=\277\007\222=\360\031\277\275\305/\365\274~(c=\014P\306=\377\315\201<\341e|=8:\020=\032\353I<[\261\271\275)\237\014=\376\264\302<p\215_\275\214\303\346<\342~\273\274\324\3437\275\005\366\344=)\237\014=\341e|=Tp\027\275L\026\266\2757!\321\275a\362[\275\205\202\304\275\376\264\302\274\214\303\346:SW\330\275\376\264\302\274\014P\306=)\206M=E\274\324=\006\017\244=SWX<p\246\236\274\250\371m=\342~;=\206\233\203=\267\224q=7!\321\274b\013\233\275\014P\306=\024\252\247\275\032\353\311\274\"E\253=\214\303f=\341e|\275\214\303\346\272~A\242\275\032\353\311=\315\242\225\275\377\315\201\274\215\334\245\275b\013\233\275\376\264\302<SW\330<\342~\273\274\342~\273\274E\274\324=Tp\227\274b\013\033\275\324\343\267\275\206\233\203\275\367Z\341=\305/\365<Tp\227=7!\321=w\347\300=\267\2550\2758:\220\273p\215_\275\"E\253=\351\330\234\275\251\022\255=\214\303f\273\351\330\234\275\377\315\201<\033\004\211=\376\264\302\274p\246\236\274\342~\273\275Tp\227\274\215\334\245<\005\366\344\275\206\233\203=SWX=[\261\271=\214\303f=\314\211\326=\376\264B\275\260l\216\275Tp\027\275[\261\271\275p\215\337=\377\315\201\274\032\353\311\273\323\312x=\267\224q\275~A\"\275Tp\227<\251\022\255<\033\004\211<~(c\275\251\022-;p\246\236\275\251\022-<\342~\273<\215\334\245<\250\371\355<p\246\036\275~A\242\275\032\353I=\033\004\211=SWX\2748:\220\2738:\220=\332$\332=\214\303f\275\251\022\255<~(\343=\032\353\311;\360\031\277=\305H\264\275\267\255\260=\223\035\310\275\305/u=\314\211\326=7!\321=[\261\271=\033\004\211\275Tp\227=Tp\027\275\250\371m\275\ri\005=\242\321\212\275\323\312x\275\342~;\275p\246\036=iL\275=8:\020\275\351\277\335=\251\022-\275\376\264\302=\014P\306=\005\366\344\275\341e|\275\267\224q\275\032\353\311\273\342~\273\275[\261\271\275\033\004\211\275L\026\266=p\246\236\274\014PF=\315\242\225=SWX\275)\237\014=\377\315\001=\033\004\t\2758:\020\274~A\"\275\351\330\234=SWX<E\274\324\275b\013\033=)\237\214\275\324\3437=F\325\023=\242\270\313\275\233w)=\367s\240\275\377\315\201=\214\303\346\273\377\315\201\274SWX=[\261\271=\267\2550\275E\274\324\275\242\321\212=\242\ ...
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/conv2/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "\214\303f:"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Constant_output_0"
#     raw_data: "\345\342i9"
#   }
#   initializer {
#     data_type: 1
#     name: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Constant_output_0"
#     raw_data: "\267\223|9"
#   }
#   initializer {
#     data_type: 1
#     name: "/fc/input_quant/export_handler/Constant_output_0"
#     raw_data: "\377o\3458"
#   }
#   initializer {
#     dims: 5
#     dims: 16
#     dims: 1
#     dims: 1
#     data_type: 1
#     name: "/fc/weight_quant/export_handler/Constant_output_0"
#     raw_data: "\360\374\254=u\236{<\tC\035\276\010\323o>k\243\007\276\010\323\357\275\277pL>\217T\031\276\246*\334<\313\223D\275\330\266\274=\330\266<\276\373\257w>\313\223D\276\246*\\\276\264\005+>\330\266\274\275\216\344k=\"\211\r\276\344\331\264\275\232\007\344=\tC\235\275u\236\373;\246*\334<-\364.>\246*\334<E\202H>\344\3314>\277p\314=u\236\373\274\234w\021>\277pL\275\246*\334\274\216\344\353=\232\007\344\275u\236\373\274-\364.>Q\355i>:\027\'>\313\223D\2768\247y\276\313\333m>Q\355i\276R]\027>R]\027\276\201\301\363\275\360\374,\276\330\266\274=R]\027>\"\211\r=u\236\373=9_\320\275_\200\017>\330\266<>\373\257w>\277p\314=\264\005+\276\250\232\t\276\330\266<\276\263MT=\344\331\264\275\264\005+\276\330\266\274\273\360DV>\330\266\274\273\313\333m>u\236{\274\tC\035<\2031\241=-\364.\276\246*\\\276\247\3422\276\"\211\215\274\216\344\353=_\200\017>]\020b\276\024\366\347=\232\007\344\275\360\374,>\277pL>"
#   }
#   initializer {
#     data_type: 1
#     name: "/fc/weight_quant/export_handler/Constant_1_output_0"
#     raw_data: "u\236\373:"
#   }
#   initializer {
#     dims: 3
#     data_type: 7
#     name: "/Constant_output_0"
#     raw_data: "\001\000\000\000\000\000\000\000\377\377\377\377\377\377\377\377\001\000\000\000\000\000\000\000"
#   }
#   input {
#     name: "x.721"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "100"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/inp_quant/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/conv1/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/conv1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/conv2/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/conv2/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.0/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/conv1/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/conv1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 4
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/conv2/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/conv2/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.1/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/conv1/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/conv1/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 8
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/conv2/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/conv2/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/relu_after_conv/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/temporal_blocks.2/relu_after_residual/act_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 256
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/fc/input_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
#   value_info {
#     name: "/fc/weight_quant/export_handler/Quant_output_0"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 1
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   domain: ""
#   version: 9
# }
# opset_import {
#   domain: "onnx.brevitas"
#   version: 1
# }
